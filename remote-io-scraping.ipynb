# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# # Remote.io request

# %% [markdown]
# ## Find pagination length - Does this make sense?
# I'm able to find the number of element in each page but not the number of pages

# %%
url = 'https://www.remote.io/remote-jobs'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'lxml')

job_offers_length = len(soup.find_all('h3', attrs ={'class':'job-listing-title'}))
job_offers_length
# Out:
# 20

# %% [markdown]
# Chose 85 for the pagination lenght because it is around the 85th page that the jobs have more 4 months

# %%
# pagination_length = 50
pagination_length = 85


urls = ['https://www.remote.io/remote-jobs?p=' + str(i) for i in range(1,pagination_length)]

responses =[requests.get(url) for url in urls]

# %%
soups = [BeautifulSoup(response.content,'lxml') for response in responses]

# %% [markdown]
# ## Find all the job titles

# %%
all_h3 = [soup.find_all('h3', attrs ={'class':'job-listing-title'}) for soup in soups]
titles = [sublist.text for h3 in all_h3 for sublist in h3]

# %% [markdown]
# ## Find all the links to job description & request

# %%
all_links = [soup.find_all('a', attrs ={'class':'list-apply-button'}) for soup in soups]
links = ['https://www.remote.io' + sublist['href'] for a in all_links for sublist in a]

# %%
responses =[requests.get(url) for url in links]

# %%
soups = [BeautifulSoup(response.content,'lxml') for response in responses]

# %%
single_pages = [soup.find('div', attrs= {'class':'single-page-section'}).text for soup in soups]

# %% [markdown]
# ## Find Experience Level

# %%
level = pd.read_json('golden-source-classified.json')
pattern = r'\b|\b'.join(level['remote_project']['level'])

entry_levels = [(set(re.findall(pattern, str(job).lower()))) for job in single_pages]
entry_levels

entry_levels_clean = []

for level in entry_levels:
    if level.intersection({'senior','experienced','sr','sr.','manager'}):
        entry_levels_clean.append('senior')
    elif level.intersection({'junior','jr','jr.'}):
        entry_levels_clean.append('junior')
    else:
        entry_levels_clean.append('other')

# %% [markdown]
# ## Find technologies

# %%
technologies = pd.read_json('golden-source-classified.json')

pattern_languages = '|'.join(technologies['remote_project']['technologies']['languages'])
pattern_web_frameworks = '|'.join(technologies['remote_project']['technologies']['web_frameworks'])
pattern_libraries = '|'.join(technologies['remote_project']['technologies']['other_frameworks_libraries_tools'])
pattern_databases = '|'.join(technologies['remote_project']['technologies']['databases'])
pattern_platforms = '|'.join(technologies['remote_project']['technologies']['platforms'])
pattern_other = '|'.join(technologies['remote_project']['technologies']['other_habilities'])

pattern_all_technologies = pattern_languages + '|' + pattern_web_frameworks + '|' + pattern_libraries + '|' + pattern_databases + '|' +pattern_platforms + '|' +pattern_other

# %%
languages = [list(set(re.findall(pattern_languages,str(tag).replace("-"," ").lower()))) for tag in single_pages]
web_frameworks = [list(set(re.findall(pattern_web_frameworks,str(tag).replace("-"," ").lower()))) for tag in single_pages]
libraries = [list(set(re.findall(pattern_libraries,str(tag).replace("-"," ").lower()))) for tag in single_pages]
databases = [list(set(re.findall(pattern_databases,str(tag).replace("-"," ").lower()))) for tag in single_pages]
platforms = [list(set(re.findall(pattern_platforms,str(tag).replace("-"," ").lower()))) for tag in single_pages]
other = [list(set(re.findall(pattern_other,str(tag).replace("-"," ").lower()))) for tag in single_pages]

# %%
# single_page_words = [list(set(re.findall(pattern, text.lower().replace("-"," "))))for text in single_pages]
# single_page_words
# Out:
# [['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['php', 'html', 'javascript', 'angular', 'css'],
#  ['bash',
#   'sass',
#   'react',
#   'postgresql',
#   'html',
#   'javascript',
#   'docker',
#   'shell',
#   'css',
#   'ruby'],
#  ['react', 'ruby'],
#  [],
#  [],
#  ['machine learning'],
#  ['wordpress', 'rust'],
#  [],
#  ['oracle'],
#  ['rust', 'scala'],
#  [],
#  [],
#  ['cordova'],
#  [],
#  ['javascript'],
#  ['sql',
#   'vue',
#   'amazon web services',
#   'python',
#   'django',
#   'react',
#   'postgresql',
#   'angular'],
#  ['ansible',
#   'python',
#   'java',
#   'django',
#   'postgresql',
#   'html',
#   'javascript',
#   'docker',
#   'scala',
#   'kubernetes',
#   'css'],
#  [],
#  ['java', 'python', 'docker', 'ruby'],
#  ['sql', 'tensorflow', 'pandas', 'pytorch', 'machine learning'],
#  ['redis',
#   'mongodb',
#   'amazon web services',
#   'node',
#   'typescript',
#   'docker',
#   'machine learning'],
#  ['amazon web services',
#   'python',
#   'java',
#   'sass',
#   'c++',
#   'javascript',
#   'swift',
#   'ruby'],
#  ['sql', 'mongodb', 'html', 'javascript', 'node', 'express', 'angular', 'css'],
#  ['sql', 'rust', 'amazon web services', 'python', 'javascript', 'powershell'],
#  ['rust'],
#  [],
#  [],
#  [],
#  [],
#  ['java', 'swift', 'objective c'],
#  ['rust'],
#  [],
#  [],
#  [],
#  ['scala'],
#  ['redis', 'javascript', 'node', 'typescript', 'graphql', 'apollo', 'nosql'],
#  ['kotlin', 'react', 'postgresql', 'typescript', 'graphql'],
#  ['html'],
#  ['ansible', 'bash', 'amazon web services', 'docker', 'machine learning'],
#  ['angular'],
#  ['sql', 'java', 'php', 'wordpress', 'elasticsearch', 'scala'],
#  ['swift', 'objective c'],
#  ['redis', 'heroku', 'react', 'javascript', 'rust', 'ruby'],
#  [],
#  [],
#  ['powershell', 'shell'],
#  [],
#  ['scala', 'javascript', 'php'],
#  [],
#  ['python', 'javascript'],
#  ['sql', 'oracle'],
#  ['sass', 'spring'],
#  [],
#  ['machine learning'],
#  ['powershell', 'python', 'docker', 'kubernetes', 'ruby'],
#  [],
#  ['sql', 'jquery', 'html', 'javascript', 'microsoft sql server', 'css'],
#  ['react native',
#   'amazon web services',
#   'python',
#   'react',
#   'html',
#   'javascript',
#   'docker',
#   'css'],
#  ['sql', 'java', 'spring', 'react', 'html', 'javascript', 'docker', 'css'],
#  ['oracle'],
#  [],
#  [],
#  [],
#  [],
#  ['html', 'javascript', 'typescript', 'angular', 'css'],
#  ['react native', 'kotlin', 'cordova', 'swift', 'flutter'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['google cloud platform'],
#  [],
#  [],
#  [],
#  [],
#  ['machine learning'],
#  ['sql', 'jquery', 'vue', 'react', 'html', 'javascript', 'css', 'ruby'],
#  ['rust'],
#  [],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['react', 'rust', 'javascript'],
#  ['sql', 'react', 'javascript', 'node', 'express', 'rust'],
#  ['react native', 'react', 'rust'],
#  ['python', 'sql'],
#  ['rust', 'javascript'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['react native',
#   'sql',
#   'redis',
#   'heroku',
#   'react',
#   'postgresql',
#   'rust',
#   'ruby'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['rust', 'swift', 'objective c'],
#  ['sql', 'docker', 'javascript', 'rust', 'ruby'],
#  ['html', 'sql', 'css', 'angular'],
#  ['python'],
#  ['react native'],
#  ['oracle'],
#  [],
#  [],
#  [],
#  ['ansible', 'elixir', 'amazon web services', 'cassandra', 'postgresql'],
#  ['docker',
#   'amazon web services',
#   'sass',
#   'react bootstrap',
#   'node',
#   'angular',
#   'graphql',
#   'scala'],
#  ['scala'],
#  ['rust'],
#  [],
#  ['scala'],
#  ['machine learning'],
#  ['scala'],
#  ['python', 'java'],
#  [],
#  ['vue',
#   'amazon web services',
#   'react',
#   'javascript',
#   'node',
#   'angular',
#   'graphql',
#   'apollo'],
#  ['vue',
#   'react',
#   'javascript',
#   'node',
#   'typescript',
#   'angular',
#   'graphql',
#   'apollo'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['sql', 'vue', 'react', 'javascript', 'angular', 'docker', 'kubernetes'],
#  [],
#  ['sql', 'php'],
#  [],
#  [],
#  [],
#  [],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['scala'],
#  [],
#  ['html', 'css'],
#  [],
#  [],
#  [],
#  ['python', 'c++'],
#  ['redis',
#   'sql',
#   'ansible',
#   'amazon web services',
#   'python',
#   'puppet',
#   'cassandra',
#   'hadoop',
#   'postgresql',
#   'javascript',
#   'docker',
#   'kubernetes',
#   'ruby'],
#  ['java', 'javascript', 'css'],
#  ['sql'],
#  [],
#  [],
#  [],
#  ['redis',
#   'sql',
#   'ansible',
#   'amazon web services',
#   'python',
#   'puppet',
#   'cassandra',
#   'hadoop',
#   'postgresql',
#   'javascript',
#   'docker',
#   'kubernetes',
#   'ruby'],
#  [],
#  ['sql'],
#  ['sql', 'python', 'javascript', 'node', 'machine learning', 'scala', 'ruby'],
#  [],
#  [],
#  ['sql', 'express'],
#  [],
#  ['html', 'css'],
#  ['html', 'css'],
#  ['spring'],
#  ['scala'],
#  [],
#  [],
#  [],
#  ['react native', 'vue', 'java', 'react', 'angular', 'scala'],
#  ['kotlin',
#   'java',
#   'python',
#   'php',
#   'react',
#   'javascript',
#   'node',
#   'typescript',
#   'scala'],
#  ['docker', 'sql'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['rust'],
#  ['redis',
#   'python',
#   'sass',
#   'react bootstrap',
#   'react',
#   'javascript',
#   'shopify',
#   'scala'],
#  ['python', 'java', 'golang', 'c++', 'javascript', 'scala'],
#  ['scala', 'spring'],
#  [],
#  [],
#  ['python', 'scala', 'powershell', 'shell'],
#  ['java', 'react', 'node'],
#  ['java',
#   'cassandra',
#   'golang',
#   'spring',
#   'c++',
#   'docker',
#   'scala',
#   'kubernetes',
#   'machine learning'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['java', 'python', 'elasticsearch', 'javascript', 'nosql', 'kubernetes'],
#  ['react native',
#   'graphql',
#   'mongodb',
#   'tensorflow',
#   'kotlin',
#   'react',
#   'firebase',
#   'dart',
#   'swift',
#   'nosql',
#   'flutter',
#   'machine learning'],
#  ['wordpress'],
#  ['react native', 'sql', 'javascript', 'node', 'express'],
#  ['xamarin', 'sql', 'redis', 'graphql'],
#  ['javascript', 'spring'],
#  ['sql',
#   'amazon web services',
#   'java',
#   'spring',
#   'nosql',
#   'javascript',
#   'express',
#   'angular',
#   'scala',
#   'oracle'],
#  ['docker', 'java', 'spring', 'express', 'graphql'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['scala'],
#  [],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['sql', 'jquery', 'react', 'html', 'javascript', 'css'],
#  ['kotlin', 'java', 'python', 'c++', 'javascript', 'chromium', 'rust'],
#  ['react', 'elasticsearch', 'typescript', 'rust', 'kubernetes', 'ruby'],
#  ['react native',
#   'redis',
#   'rust',
#   'python',
#   'react',
#   'node',
#   'typescript',
#   'graphql',
#   'kubernetes',
#   'ruby'],
#  ['ansible',
#   'amazon web services',
#   'python',
#   'postgresql',
#   'scala',
#   'shell',
#   'ruby'],
#  ['ansible',
#   'vue',
#   'python',
#   'react',
#   'postgresql',
#   'javascript',
#   'elasticsearch',
#   'html',
#   'docker',
#   'css'],
#  ['python',
#   'elasticsearch',
#   'postgresql',
#   'html',
#   'javascript',
#   'docker',
#   'css'],
#  [],
#  ['scala'],
#  [],
#  ['scala'],
#  ['amazon web services'],
#  ['scala'],
#  ['python', 'ansible', 'docker', 'flask'],
#  [],
#  ['html', 'javascript', 'css'],
#  [],
#  [],
#  [],
#  ['amazon web services',
#   'react',
#   'postgresql',
#   'javascript',
#   'node',
#   'rust',
#   'scala'],
#  ['sql'],
#  ['scala'],
#  ['sql', 'react', 'javascript', 'node', 'express', 'rust'],
#  ['react native', 'react', 'rust'],
#  ['react native',
#   'sql',
#   'redis',
#   'heroku',
#   'react',
#   'postgresql',
#   'rust',
#   'ruby'],
#  ['rust', 'javascript'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['python', 'sql'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['react', 'rust', 'javascript'],
#  ['amazon web services', 'java', 'python', 'javascript', 'node', 'rust'],
#  ['mongodb', 'python', 'react', 'javascript', 'node', 'angular'],
#  ['rust'],
#  [],
#  ['javascript'],
#  [],
#  [],
#  [],
#  [],
#  ['oracle'],
#  [],
#  [],
#  ['oracle'],
#  ['powershell',
#   'ansible',
#   'bash',
#   'amazon web services',
#   'python',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['react native', 'elixir', 'docker', 'golang', 'graphql', 'scala', 'ruby'],
#  ['mongodb', 'javascript', 'node', 'vue'],
#  ['c++'],
#  ['html', 'javascript', 'amazon web services', 'css'],
#  ['redis',
#   'sql',
#   'amazon web services',
#   'google cloud platform',
#   'scala',
#   'kubernetes'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sql'],
#  ['scala'],
#  [],
#  [],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  [],
#  ['python'],
#  ['html', 'javascript', 'sql', 'angular'],
#  ['sql',
#   'amazon web services',
#   'python',
#   'hadoop',
#   'php',
#   'wordpress',
#   'scala',
#   'machine learning'],
#  ['sql', 'google cloud platform', 'react', 'javascript', 'node', 'angular'],
#  ['react native',
#   'amazon web services',
#   'python',
#   'react',
#   'html',
#   'javascript',
#   'docker',
#   'css'],
#  ['swift', 'objective c', 'scala'],
#  ['redis',
#   'sql',
#   'amazon web services',
#   'google cloud platform',
#   'scala',
#   'kubernetes'],
#  ['bash', 'python', 'powershell', 'scala', 'kubernetes'],
#  ['react', 'sql', 'javascript'],
#  ['redis',
#   'python',
#   'cassandra',
#   'golang',
#   'elasticsearch',
#   'scala',
#   'machine learning'],
#  ['sql',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'laravel',
#   'rust',
#   'scala',
#   'css'],
#  ['python', 'sql'],
#  [],
#  ['java', 'python', 'html', 'javascript', 'docker', 'css'],
#  ['sql'],
#  [],
#  ['kubernetes'],
#  [],
#  ['docker',
#   'vue',
#   'java',
#   'c++',
#   'react',
#   'postgresql',
#   'node',
#   'typescript',
#   'angular',
#   'rust'],
#  ['google cloud platform', 'react', 'node', 'angular', 'scala'],
#  [],
#  [],
#  ['sql',
#   'jquery',
#   'java',
#   'python',
#   'c++',
#   'php',
#   'postgresql',
#   'javascript',
#   'laravel',
#   'powershell',
#   'shell',
#   'css',
#   'ruby'],
#  ['sql', 'react', 'html', 'typescript', 'css'],
#  ['sql',
#   'python',
#   'cassandra',
#   'hadoop',
#   'php',
#   'javascript',
#   'node',
#   'laravel',
#   'typescript',
#   'scala',
#   'nosql'],
#  ['sql', 'java', 'html', 'javascript', 'css'],
#  ['sql',
#   'amazon web services',
#   'rabbitmq',
#   'javascript',
#   'node',
#   'postgresql',
#   'rust'],
#  [],
#  [],
#  ['sql',
#   'jquery',
#   'java',
#   'python',
#   'c++',
#   'php',
#   'postgresql',
#   'javascript',
#   'laravel',
#   'powershell',
#   'shell',
#   'css',
#   'ruby'],
#  [],
#  [],
#  [],
#  [],
#  ['ruby'],
#  ['react', 'html', 'javascript', 'css'],
#  ['python'],
#  ['sql', 'google cloud platform', 'react', 'javascript', 'node', 'angular'],
#  ['amazon web services', 'docker', 'scala', 'kubernetes', 'ruby'],
#  ['oracle', 'express', 'spring'],
#  ['java', 'spring'],
#  ['javascript', 'vue', 'css'],
#  [],
#  [],
#  [],
#  ['sql', 'sass'],
#  ['python', 'scala', 'flask'],
#  ['javascript', 'vue'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['oracle', 'express'],
#  [],
#  ['react', 'html', 'javascript', 'node', 'rust', 'nosql', 'css'],
#  ['mongodb', 'amazon web services', 'react', 'node', 'typescript', 'docker'],
#  ['redis',
#   'sql',
#   'ansible',
#   'python',
#   'java',
#   'django',
#   'elasticsearch',
#   'postgresql',
#   'javascript',
#   'rabbitmq',
#   'scala'],
#  ['sql', 'bash', 'java', 'postgresql', 'clojure', 'docker', 'scala'],
#  ['html', 'javascript', 'express', 'css'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['mongodb', 'react', 'javascript', 'node', 'docker', 'css'],
#  ['sql', 'sass', 'html', 'javascript', 'typescript', 'angular', 'css'],
#  ['java', 'sql', 'html', 'oracle'],
#  ['java', 'sql', 'html', 'oracle'],
#  ['sql', 'react', 'javascript', 'node', 'express', 'rust'],
#  [],
#  ['sql', 'oracle'],
#  ['java', 'node', 'angular'],
#  [],
#  [],
#  [],
#  [],
#  ['rust'],
#  [],
#  ['python', 'php', 'django', 'javascript', 'machine learning'],
#  ['rust', 'javascript'],
#  ['java', 'docker'],
#  ['python', 'sql'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['react', 'rust', 'node', 'amazon web services'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['redis',
#   'sql',
#   'heroku',
#   'react',
#   'postgresql',
#   'elasticsearch',
#   'rust',
#   'ruby'],
#  ['react', 'rust', 'javascript'],
#  ['react native', 'react', 'rust'],
#  ['mongodb', 'apache', 'amazon web services', 'machine learning'],
#  ['amazon web services', 'kotlin', 'python', 'postgresql', 'scala', 'ruby'],
#  ['java', 'python', 'typescript', 'docker', 'kubernetes'],
#  ['bash',
#   'vue',
#   'sass',
#   'php',
#   'wordpress',
#   'html',
#   'javascript',
#   'node',
#   'react',
#   'laravel',
#   'angular',
#   'docker',
#   'shell',
#   'css'],
#  ['sql',
#   'python',
#   'java',
#   'spring',
#   'react',
#   'html',
#   'javascript',
#   'docker',
#   'kubernetes',
#   'flask',
#   'css',
#   'ruby'],
#  ['sql',
#   'python',
#   'java',
#   'spring',
#   'react',
#   'html',
#   'javascript',
#   'express',
#   'flask',
#   'css',
#   'ruby'],
#  ['python', 'php', 'javascript', 'scala', 'nosql'],
#  ['sql', 'jquery', 'html', 'javascript', 'express', 'css'],
#  [],
#  [],
#  ['redis',
#   'mongodb',
#   'amazon web services',
#   'sass',
#   'react',
#   'elasticsearch',
#   'javascript',
#   'node',
#   'express',
#   'scala',
#   'css'],
#  ['amazon web services',
#   'java',
#   'python',
#   'google cloud platform',
#   'kubernetes',
#   'ruby'],
#  [],
#  ['docker', 'bash', 'golang', 'ruby'],
#  ['sql',
#   'docker',
#   'amazon web services',
#   'kotlin',
#   'sass',
#   'php',
#   'react',
#   'node',
#   'angular',
#   'rust',
#   'scala'],
#  ['python', 'sql', 'amazon web services'],
#  ['java', 'react', 'rust'],
#  ['java'],
#  ['xamarin'],
#  [],
#  ['cassandra', 'ansible'],
#  [],
#  ['dart', 'ruby'],
#  [],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['python', 'javascript', 'typescript'],
#  ['java', 'python'],
#  ['html', 'javascript'],
#  ['sql', 'vue', 'python', 'php', 'elasticsearch', 'laravel', 'rust'],
#  [],
#  ['java', 'spring', 'node', 'angular', 'scala'],
#  ['redis',
#   'python',
#   'django',
#   'react',
#   'javascript',
#   'node',
#   'typescript',
#   'angular',
#   'scala',
#   'ruby'],
#  [],
#  ['python', 'django', 'postgresql', 'html', 'css'],
#  ['python', 'sql', 'amazon web services'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['rust'],
#  [],
#  [],
#  [],
#  [],
#  ['sql',
#   'ansible',
#   'amazon web services',
#   'java',
#   'spring',
#   'mariadb',
#   'apache',
#   'dynamodb',
#   'docker',
#   'kubernetes'],
#  ['sql',
#   'python',
#   'django',
#   'react',
#   'html',
#   'javascript',
#   'node',
#   'laravel',
#   'angular',
#   'css'],
#  [],
#  ['php', 'wordpress', 'html', 'javascript', 'express', 'scala', 'css'],
#  ['python'],
#  ['react native', 'react', 'rust'],
#  ['sql',
#   'vue',
#   'amazon web services',
#   'php',
#   'html',
#   'javascript',
#   'laravel',
#   'css'],
#  ['sql',
#   'drupal',
#   'sass',
#   'php',
#   'postgresql',
#   'javascript',
#   'node',
#   'angular',
#   'docker',
#   'css'],
#  ['php', 'react', 'node', 'docker', 'scala'],
#  ['mariadb', 'sql', 'kubernetes'],
#  ['docker', 'kubernetes', 'c++'],
#  ['ansible',
#   'vue',
#   'amazon web services',
#   'java',
#   'heroku',
#   'node',
#   'docker',
#   'kubernetes',
#   'ruby'],
#  [],
#  [],
#  ['java', 'sql'],
#  [],
#  ['assembly'],
#  ['c++'],
#  [],
#  [],
#  ['express', 'javascript', 'golang', 'amazon web services'],
#  ['drupal', 'php', 'html', 'javascript', 'rust', 'scala', 'css'],
#  ['sql',
#   'jquery',
#   'sass',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'node',
#   'laravel',
#   'docker',
#   'css'],
#  ['amazon web services',
#   'cassandra',
#   'apache',
#   'docker',
#   'scala',
#   'kubernetes',
#   'shell',
#   'machine learning'],
#  ['sql', 'css', 'angular'],
#  ['sql', 'vue', 'php', 'javascript', 'laravel', 'scala', 'css'],
#  ['google cloud platform', 'amazon web services'],
#  ['rust', 'scala', 'python', 'google cloud platform'],
#  ['python', 'sass', 'django', 'kubernetes', 'machine learning'],
#  ['rust'],
#  ['redis',
#   'sql',
#   'ansible',
#   'python',
#   'puppet',
#   'cassandra',
#   'google cloud platform',
#   'hadoop',
#   'postgresql',
#   'javascript',
#   'docker',
#   'kubernetes',
#   'ruby'],
#  ['redis',
#   'sql',
#   'ansible',
#   'java',
#   'puppet',
#   'python',
#   'cassandra',
#   'hadoop',
#   'google cloud platform',
#   'postgresql',
#   'javascript',
#   'docker',
#   'kubernetes',
#   'ruby'],
#  ['sql',
#   'mongodb',
#   'amazon web services',
#   'kotlin',
#   'java',
#   'cassandra',
#   'spring',
#   'elasticsearch',
#   'apache',
#   'clojure',
#   'express',
#   'scala',
#   'nosql'],
#  ['sql',
#   'mongodb',
#   'jquery',
#   'amazon web services',
#   'python',
#   'django',
#   'elasticsearch',
#   'postgresql',
#   'apache',
#   'javascript',
#   'angular',
#   'nosql',
#   'flask'],
#  ['react native'],
#  ['sql', 'amazon web services', 'python', 'shopify', 'flask'],
#  ['vue', 'react', 'elasticsearch', 'node', 'typescript', 'dynamodb'],
#  ['redis', 'sql', 'python', 'javascript', 'node', 'dynamodb', 'ruby'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  [],
#  ['sql', 'php'],
#  [],
#  ['ansible',
#   'bash',
#   'java',
#   'python',
#   'javascript',
#   'typescript',
#   'docker',
#   'kubernetes'],
#  [],
#  ['sql', 'ansible', 'python', 'puppet', 'elasticsearch', 'postgresql', 'ruby'],
#  [],
#  [],
#  ['python', 'django', 'postgresql', 'docker', 'scala'],
#  ['redis',
#   'sql',
#   'heroku',
#   'react',
#   'postgresql',
#   'elasticsearch',
#   'rust',
#   'ruby'],
#  ['redis',
#   'ansible',
#   'bash',
#   'amazon web services',
#   'python',
#   'docker',
#   'kubernetes'],
#  ['java',
#   'python',
#   'spring',
#   'react',
#   'html',
#   'javascript',
#   'typescript',
#   'angular',
#   'graphql',
#   'scala',
#   'flask',
#   'css'],
#  [],
#  ['sql'],
#  [],
#  [],
#  ['kubernetes', 'amazon web services'],
#  ['react', 'c++', 'machine learning'],
#  ['python', 'scala', 'google cloud platform', 'amazon web services'],
#  ['rust', 'java', 'javascript'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['react native', 'sql', 'html', 'javascript', 'node', 'docker', 'kubernetes'],
#  ['react', 'rust', 'javascript'],
#  ['rust'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['sql', 'javascript', 'node', 'amazon web services'],
#  ['react', 'rust', 'node', 'amazon web services'],
#  ['react', 'rust', 'amazon web services'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['react native', 'kotlin', 'react', 'node', 'express', 'swift'],
#  [],
#  [],
#  ['scala'],
#  ['sql', 'postgresql', 'javascript', 'node', 'docker', 'scala', 'kubernetes'],
#  [],
#  [],
#  ['express'],
#  [],
#  ['html', 'sql', 'microsoft sql server'],
#  ['java', 'react'],
#  ['react native', 'react', 'javascript', 'node', 'express', 'nosql'],
#  ['scala',
#   'amazon web services',
#   'python',
#   'django',
#   'react',
#   'rust',
#   'swift',
#   'kubernetes'],
#  ['rust', 'sql'],
#  [],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['php', 'wordpress', 'html', 'javascript', 'css'],
#  ['rust'],
#  [],
#  [],
#  [],
#  ['machine learning'],
#  ['sql', 'vue', 'react', 'html', 'javascript', 'apache', 'angular', 'css'],
#  ['php', 'angular'],
#  ['react', 'javascript', 'node', 'vue'],
#  ['vue', 'python', 'django', 'react', 'html', 'javascript', 'apollo'],
#  ['react', 'javascript', 'node', 'typescript', 'graphql', 'apollo'],
#  ['react', 'javascript', 'react native', 'node'],
#  ['react native', 'javascript', 'node', 'express', 'swift', 'nosql'],
#  ['react native', 'objective c', 'java', 'javascript', 'swift'],
#  ['ansible',
#   'python',
#   'hadoop',
#   'django',
#   'elasticsearch',
#   'docker',
#   'kubernetes'],
#  ['redis',
#   'python',
#   'django',
#   'react',
#   'html',
#   'javascript',
#   'scala',
#   'kubernetes',
#   'css'],
#  ['vue', 'react', 'html', 'typescript', 'angular', 'css'],
#  ['rust', 'elixir', 'golang'],
#  ['graphql', 'kubernetes', 'docker', 'amazon web services'],
#  ['elixir',
#   'docker',
#   'amazon web services',
#   'golang',
#   'rabbitmq',
#   'apache',
#   'rust',
#   'kubernetes'],
#  ['express'],
#  ['java', 'scala', 'spring'],
#  ['scala'],
#  ['unreal engine', 'python', 'java', 'c++', 'docker', 'scala', 'shell'],
#  [],
#  [],
#  [],
#  [],
#  ['wordpress'],
#  [],
#  ['rust'],
#  ['react', 'rust', 'javascript'],
#  ['amazon web services',
#   'java',
#   'spring',
#   'mariadb',
#   'html',
#   'angular',
#   'css'],
#  ['amazon web services', 'html', 'javascript', 'rust', 'scala', 'css'],
#  ['drupal', 'python', 'puppet', 'golang', 'docker'],
#  ['elasticsearch', 'sql', 'javascript', 'css'],
#  ['docker', 'elasticsearch', 'kubernetes'],
#  ['python', 'google cloud platform', 'ruby'],
#  ['sql', 'postgresql', 'javascript', 'node', 'express'],
#  ['swift'],
#  ['java',
#   'react',
#   'html',
#   'javascript',
#   'node',
#   'apache',
#   'express',
#   'dynamodb',
#   'angular',
#   'nosql',
#   'css'],
#  ['sql', 'ansible', 'python', 'docker', 'flask'],
#  ['kotlin', 'java', 'python', 'c++', 'javascript', 'chromium'],
#  ['scala', 'amazon web services'],
#  ['redis',
#   'docker',
#   'java',
#   'javascript',
#   'node',
#   'typescript',
#   'rust',
#   'scala',
#   'kubernetes'],
#  ['rust', 'sql'],
#  ['sql',
#   'jquery',
#   'html',
#   'javascript',
#   'angular',
#   'rust',
#   'microsoft sql server'],
#  [],
#  ['sass'],
#  [],
#  ['react', 'javascript', 'node', 'rust', 'scala', 'ruby'],
#  ['typescript', 'angular'],
#  ['sql', 'vue', 'php'],
#  ['jquery', 'html', 'javascript', 'angular', 'rust', 'microsoft sql server'],
#  ['sql',
#   'amazon web services',
#   'java',
#   'python',
#   'puppet',
#   'spring',
#   'docker',
#   'scala',
#   'nosql'],
#  ['ansible',
#   'bash',
#   'java',
#   'python',
#   'cassandra',
#   'sass',
#   'swift',
#   'shell',
#   'ruby'],
#  ['sql',
#   'jquery',
#   'html',
#   'javascript',
#   'angular',
#   'rust',
#   'microsoft sql server'],
#  ['scala'],
#  ['sql', 'jquery', 'react', 'html', 'javascript', 'css'],
#  ['tensorflow',
#   'bash',
#   'amazon web services',
#   'pandas',
#   'kotlin',
#   'python',
#   'java',
#   'pytorch',
#   'docker',
#   'machine learning'],
#  ['ansible',
#   'amazon web services',
#   'java',
#   'python',
#   'google cloud platform',
#   'puppet',
#   'php',
#   'machine learning',
#   'ruby'],
#  ['sql', 'python', 'apache', 'scala', 'machine learning'],
#  ['sql', 'php', 'html', 'javascript', 'laravel', 'scala', 'css'],
#  ['redis',
#   'sql',
#   'docker',
#   'amazon web services',
#   'python',
#   'elasticsearch',
#   'apache',
#   'rust',
#   'scala',
#   'kubernetes'],
#  ['python'],
#  [],
#  ['sql', 'heroku', 'react', 'javascript', 'ruby'],
#  ['python'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['react native', 'objective c', 'react', 'graphql', 'swift'],
#  ['jquery', 'php', 'wordpress', 'html', 'javascript', 'canvas', 'css'],
#  ['sass', 'firebase', 'node', 'typescript', 'angular', 'css'],
#  ['kubernetes'],
#  ['sql',
#   'bash',
#   'amazon web services',
#   'pandas',
#   'python',
#   'google cloud platform',
#   'apache',
#   'docker',
#   'scala',
#   'flask',
#   'machine learning'],
#  ['java', 'swift', 'objective c', 'c++'],
#  ['sql', 'vue', 'python', 'django', 'javascript', 'express'],
#  [],
#  ['rust', 'html', 'express', 'css'],
#  ['python', 'php', 'javascript', 'node', 'ruby'],
#  ['java', 'python', 'c++', 'javascript', 'ruby'],
#  ['java', 'python', 'c++', 'javascript', 'ruby'],
#  ['ansible', 'bash', 'python', 'javascript', 'express', 'shell'],
#  ['rust', 'c++'],
#  [],
#  [],
#  ['react', 'oracle'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['rust', 'java', 'javascript'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['react native', 'react', 'rust'],
#  ['react', 'rust', 'amazon web services'],
#  ['react', 'rust', 'node', 'amazon web services'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['sql', 'javascript', 'node', 'amazon web services'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['rust'],
#  ['mongodb', 'amazon web services', 'python', 'angular', 'docker', 'nosql'],
#  ['mongodb', 'amazon web services', 'python', 'docker', 'nosql'],
#  ['mongodb',
#   'amazon web services',
#   'react',
#   'elasticsearch',
#   'javascript',
#   'node',
#   'docker'],
#  ['amazon web services'],
#  ['react', 'html', 'javascript', 'node', 'express', 'scala', 'css'],
#  ['sql', 'pandas', 'python', 'docker', 'machine learning'],
#  ['xamarin'],
#  ['python', 'php', 'html', 'javascript', 'scala', 'css', 'machine learning'],
#  [],
#  [],
#  ['react', 'sass', 'javascript', 'node'],
#  ['docker', 'rabbitmq', 'sql', 'express'],
#  [],
#  [],
#  [],
#  [],
#  ['react', 'html', 'javascript', 'node', 'graphql', 'apollo'],
#  ['python', 'redis'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  [],
#  ['sql', 'shopify', 'angular'],
#  [],
#  [],
#  ['scala'],
#  ['sql',
#   'bash',
#   'amazon web services',
#   'puppet',
#   'wordpress',
#   'html',
#   'apache'],
#  ['jquery', 'vue', 'java', 'html', 'javascript', 'css'],
#  [],
#  ['react', 'puppet', 'javascript'],
#  ['sql'],
#  [],
#  ['rust'],
#  [],
#  [],
#  [],
#  ['react', 'javascript', 'typescript'],
#  ['scala'],
#  ['sql', 'oracle', 'express'],
#  ['python', 'f#'],
#  ['rust', 'python', 'flask', 'django'],
#  ['python', 'google cloud platform', 'kubernetes'],
#  ['apollo'],
#  ['apollo'],
#  [],
#  [],
#  ['scala'],
#  [],
#  [],
#  [],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['python', 'shell', 'c++'],
#  ['docker', 'python', 'amazon web services', 'angular'],
#  ['sql',
#   'jquery',
#   'sass',
#   'php',
#   'wordpress',
#   'html',
#   'javascript',
#   'css',
#   'ruby'],
#  ['redis',
#   'sql',
#   'jquery',
#   'vue',
#   'react',
#   'html',
#   'javascript',
#   'postgresql',
#   'css',
#   'ruby'],
#  ['redis',
#   'sql',
#   'amazon web services',
#   'elasticsearch',
#   'postgresql',
#   'dynamodb',
#   'microsoft sql server'],
#  ['react native', 'react', 'rust'],
#  ['mongodb', 'python', 'java', 'golang', 'postgresql', 'node', 'rust'],
#  ['rust', 'scala', 'node', 'react'],
#  ['sql',
#   'amazon web services',
#   'rust',
#   'scala',
#   'canvas',
#   'nosql',
#   'kubernetes'],
#  ['php', 'wordpress', 'node', 'laravel', 'rust'],
#  ['mongodb', 'react', 'postgresql', 'node', 'rust'],
#  ['sql',
#   'vue',
#   'amazon web services',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'laravel',
#   'angular',
#   'scala',
#   'css'],
#  [],
#  [],
#  [],
#  ['rust', 'amazon web services'],
#  ['sql',
#   'ansible',
#   'amazon web services',
#   'java',
#   'spring',
#   'elasticsearch',
#   'angular',
#   'scala'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['sql',
#   'java',
#   'mariadb',
#   'javascript',
#   'node',
#   'dynamodb',
#   'typescript',
#   'angular'],
#  ['xamarin', 'dart', 'flutter'],
#  ['rust'],
#  ['elixir', 'amazon web services', 'docker', 'scala', 'ruby'],
#  ['redis',
#   'mongodb',
#   'sass',
#   'react',
#   'elasticsearch',
#   'node',
#   'express',
#   'scala',
#   'css'],
#  ['redis',
#   'mongodb',
#   'ansible',
#   'docker',
#   'react',
#   'elasticsearch',
#   'html',
#   'node',
#   'typescript',
#   'graphql'],
#  ['javascript', 'vue'],
#  [],
#  ['sql'],
#  [],
#  [],
#  ['sql', 'node', 'amazon web services'],
#  ['react', 'rust', 'node', 'amazon web services'],
#  ['react', 'rust', 'amazon web services'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['python', 'rust', 'javascript', 'flask'],
#  ['rust'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['rust', 'java', 'javascript'],
#  ['redis', 'sql', 'mongodb', 'vue', 'react', 'angular', 'scala'],
#  ['mongodb',
#   'python',
#   'google cloud platform',
#   'php',
#   'postgresql',
#   'node',
#   'express',
#   'docker',
#   'kubernetes'],
#  ['react', 'javascript', 'node', 'dynamodb'],
#  ['java', 'sql', 'python', 'oracle'],
#  [],
#  ['react', 'puppet', 'javascript'],
#  [],
#  [],
#  ['rust'],
#  ['rust', 'swift', 'express', 'kotlin'],
#  ['redis',
#   'sql',
#   'mongodb',
#   'javascript',
#   'node',
#   'typescript',
#   'docker',
#   'kubernetes',
#   'machine learning'],
#  ['shopify'],
#  ['scala', 'sql'],
#  [],
#  ['sql', 'jquery', 'html', 'javascript', 'angular'],
#  ['sql', 'c++'],
#  ['powershell', 'scala', 'sql'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['php', 'html', 'javascript', 'angular', 'css'],
#  ['node', 'express', 'django'],
#  ['html'],
#  [],
#  ['ansible', 'docker', 'python', 'rust', 'scala', 'kubernetes'],
#  ['sql',
#   'jquery',
#   'amazon web services',
#   'python',
#   'java',
#   'django',
#   'html',
#   'javascript',
#   'postgresql',
#   'flask',
#   'css'],
#  [],
#  ['java', 'google cloud platform', 'python', 'amazon web services'],
#  [],
#  ['postgresql', 'apache'],
#  ['amazon web services', 'express', 'rust', 'scala', 'ruby'],
#  ['rust', 'react', 'javascript', 'angular'],
#  ['python', 'react', 'html', 'javascript', 'canvas', 'css'],
#  ['shopify', 'spring'],
#  ['vue'],
#  ['spring'],
#  ['sql', 'bash', 'amazon web services', 'python', 'powershell', 'scala'],
#  ['sql', 'bash', 'amazon web services', 'python', 'powershell', 'scala'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['sql',
#   'mongodb',
#   'docker',
#   'amazon web services',
#   'sass',
#   'react',
#   'postgresql',
#   'javascript',
#   'node',
#   'rabbitmq',
#   'typescript',
#   'angular',
#   'graphql',
#   'scala',
#   'nosql',
#   'css'],
#  ['sql',
#   'python',
#   'hadoop',
#   'apache',
#   'node',
#   'express',
#   'scala',
#   'flask',
#   'machine learning'],
#  ['sql',
#   'react',
#   'html',
#   'javascript',
#   'angular',
#   'docker',
#   'nosql',
#   'kubernetes'],
#  [],
#  [],
#  [],
#  [],
#  ['python', 'machine learning'],
#  ['rust', 'elasticsearch'],
#  ['rust', 'kubernetes'],
#  ['react native',
#   'sql',
#   'sass',
#   'php',
#   'react',
#   'elasticsearch',
#   'laravel',
#   'angular',
#   'docker',
#   'scala',
#   'css'],
#  ['python', 'php', 'wordpress', 'html', 'javascript', 'react', 'css', 'ruby'],
#  ['wordpress', 'php'],
#  ['apollo', 'javascript', 'angular'],
#  ['express'],
#  ['react', 'python', 'express', 'ruby'],
#  ['redis',
#   'sql',
#   'vue',
#   'python',
#   'php',
#   'django',
#   'rabbitmq',
#   'javascript',
#   'angular',
#   'graphql',
#   'nosql',
#   'flask'],
#  [],
#  [],
#  ['sql',
#   'amazon web services',
#   'python',
#   'javascript',
#   'node',
#   'express',
#   'scala'],
#  ['scala', 'javascript', 'typescript'],
#  [],
#  [],
#  ['sql',
#   'vue',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'laravel',
#   'angular',
#   'docker',
#   'nosql',
#   'css'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['docker', 'amazon web services', 'node', 'rust', 'kubernetes'],
#  ['html', 'javascript', 'css', 'angular'],
#  ['sql', 'react', 'mariadb', 'javascript', 'node', 'postgresql', 'angular'],
#  ['react', 'javascript', 'react native', 'node'],
#  ['python', 'node', 'ruby'],
#  ['tensorflow',
#   'amazon web services',
#   'pandas',
#   'python',
#   'matlab',
#   'c++',
#   'pytorch',
#   'rust',
#   'machine learning'],
#  ['java', 'javascript'],
#  ['python', 'sql', 'machine learning'],
#  [],
#  ['java', 'python', 'docker', 'kubernetes', 'machine learning'],
#  ['sql', 'node', 'amazon web services'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['react', 'rust', 'amazon web services'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'dynamodb',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['rust'],
#  ['python', 'rust', 'javascript', 'flask'],
#  ['react', 'rust', 'node', 'amazon web services'],
#  [],
#  ['java', 'postgresql', 'scala', 'spring'],
#  ['javascript', 'shell', 'c++'],
#  ['sass', 'html', 'javascript', 'angular', 'scala', 'css'],
#  ['rust'],
#  ['sql', 'vue', 'java', 'spring', 'react', 'angular', 'scala'],
#  [],
#  ['sql', 'python', 'django', 'react', 'javascript', 'typescript'],
#  ['java', 'spring'],
#  ['dart', 'flutter', 'ruby'],
#  ['machine learning'],
#  ['ansible',
#   'tensorflow',
#   'bash',
#   'python',
#   'puppet',
#   'hadoop',
#   'elasticsearch',
#   'kubernetes',
#   'shell',
#   'ruby'],
#  ['ansible', 'elixir', 'python', 'java', 'javascript', 'ruby'],
#  ['sql',
#   'objective c',
#   'kotlin',
#   'java',
#   'php',
#   'mariadb',
#   'html',
#   'javascript',
#   'swift',
#   'css'],
#  ['rust', 'scala'],
#  ['redis',
#   'sql',
#   'jquery',
#   'react native',
#   'html',
#   'javascript',
#   'scala',
#   'css'],
#  ['sql',
#   'jquery',
#   'bash',
#   'html',
#   'javascript',
#   'rabbitmq',
#   'powershell',
#   'flutter',
#   'css'],
#  ['scala', 'sql', 'nosql', 'rabbitmq'],
#  ['sql',
#   'mongodb',
#   'amazon web services',
#   'react',
#   'apache',
#   'node',
#   'typescript',
#   'express',
#   'scala',
#   'kubernetes'],
#  ['php', 'html', 'javascript', 'angular', 'css'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['python', 'react', 'angular'],
#  [],
#  [],
#  [],
#  ['rust'],
#  [],
#  ['python', 'scala', 'c++'],
#  [],
#  ['rust'],
#  ['java', 'javascript', 'vue', 'spring'],
#  ['scala', 'sql', 'css'],
#  ['ansible',
#   'bash',
#   'docker',
#   'amazon web services',
#   'python',
#   'puppet',
#   'powershell',
#   'kubernetes'],
#  [],
#  ['machine learning'],
#  [],
#  ['jquery', 'java', 'javascript', 'rust', 'scala'],
#  ['vue', 'heroku', 'postgresql', 'javascript', 'scala', 'ruby'],
#  ['php', 'wordpress', 'node', 'laravel', 'rust'],
#  ['php', 'wordpress', 'html', 'javascript', 'css'],
#  [],
#  [],
#  ['tensorflow',
#   'java',
#   'python',
#   'c++',
#   'pytorch',
#   'scala',
#   'machine learning'],
#  ['google cloud platform'],
#  ['sql', 'python', 'javascript', 'kubernetes', 'flask', 'machine learning'],
#  ['docker', 'javascript', 'python', 'angular'],
#  [],
#  [],
#  ['sass',
#   'react',
#   'html',
#   'javascript',
#   'node',
#   'typescript',
#   'graphql',
#   'scala',
#   'canvas',
#   'css'],
#  ['sql', 'amazon web services', 'python', 'postgresql', 'machine learning'],
#  ['c++'],
#  ['c++'],
#  ['redis',
#   'mongodb',
#   'amazon web services',
#   'sass',
#   'react',
#   'elasticsearch',
#   'node',
#   'express',
#   'scala',
#   'css'],
#  ['python', 'django'],
#  ['react', 'javascript', 'node', 'angular'],
#  ['swift', 'objective c'],
#  ['python', 'kubernetes', 'amazon web services', 'docker'],
#  ['redis',
#   'sql',
#   'mongodb',
#   'amazon web services',
#   'graphql',
#   'scala',
#   'nosql'],
#  ['react', 'scala'],
#  ['redis',
#   'sql',
#   'java',
#   'python',
#   'javascript',
#   'typescript',
#   'angular',
#   'scala'],
#  ['sql',
#   'ansible',
#   'amazon web services',
#   'python',
#   'puppet',
#   'postgresql',
#   'docker',
#   'scala',
#   'shell'],
#  [],
#  ['scala', 'sql'],
#  ['sql', 'spring', 'react', 'postgresql', 'javascript', 'scala', 'ruby'],
#  ['amazon web services', 'react', 'node', 'dynamodb', 'machine learning'],
#  ['react', 'dynamodb', 'node', 'machine learning'],
#  ['redis',
#   'vue',
#   'react',
#   'postgresql',
#   'javascript',
#   'node',
#   'rabbitmq',
#   'typescript',
#   'angular'],
#  ['sql', 'html', 'javascript', 'angular', 'scala', 'css'],
#  ['sql', 'node', 'amazon web services'],
#  ['jquery', 'html', 'javascript', 'typescript', 'angular', 'docker', 'css'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['react', 'rust', 'amazon web services'],
#  ['python', 'scala', 'react', 'django'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['python',
#   'react',
#   'html',
#   'javascript',
#   'postgresql',
#   'rabbitmq',
#   'angular',
#   'docker',
#   'kubernetes',
#   'css'],
#  ['drupal'],
#  ['react', 'swift'],
#  ['react', 'java', 'firebase', 'kotlin'],
#  [],
#  ['ansible', 'python', 'puppet', 'elasticsearch', 'postgresql'],
#  ['ansible', 'elixir', 'amazon web services', 'cassandra', 'postgresql'],
#  [],
#  ['scala'],
#  ['redis',
#   'jquery',
#   'heroku',
#   'html',
#   'javascript',
#   'postgresql',
#   'rust',
#   'css',
#   'ruby'],
#  ['react', 'node', 'amazon web services', 'dynamodb'],
#  ['rust'],
#  ['react', 'node', 'dynamodb'],
#  ['rust', 'sql', 'python', 'apache'],
#  ['sql',
#   'pandas',
#   'python',
#   'java',
#   'c++',
#   'apache',
#   'rust',
#   'scala',
#   'machine learning'],
#  [],
#  ['rust'],
#  ['javascript', 'css'],
#  ['mongodb',
#   'sass',
#   'react',
#   'postgresql',
#   'node',
#   'express',
#   'docker',
#   'nosql',
#   'css'],
#  [],
#  ['sql',
#   'mongodb',
#   'tensorflow',
#   'python',
#   'hadoop',
#   'elasticsearch',
#   'dynamodb',
#   'scala',
#   'machine learning'],
#  ['react', 'javascript', 'ruby'],
#  [],
#  [],
#  [],
#  ['ansible', 'python', 'docker', 'scala', 'kubernetes'],
#  ['python', 'amazon web services', 'javascript', 'typescript'],
#  ['rust', 'sql'],
#  ['rust',
#   'ansible',
#   'amazon web services',
#   'puppet',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['react', 'node', 'dynamodb'],
#  ['react', 'node', 'amazon web services', 'dynamodb'],
#  ['docker', 'rust', 'amazon web services', 'ruby'],
#  ['redis',
#   'sql',
#   'jquery',
#   'vue',
#   'react',
#   'html',
#   'javascript',
#   'postgresql',
#   'css',
#   'ruby'],
#  ['sql',
#   'jquery',
#   'sass',
#   'php',
#   'wordpress',
#   'html',
#   'javascript',
#   'css',
#   'ruby'],
#  ['sql',
#   'java',
#   'spring',
#   'nosql',
#   'javascript',
#   'express',
#   'angular',
#   'scala',
#   'oracle'],
#  ['scala', 'hadoop', 'machine learning'],
#  ['scala', 'ruby'],
#  ['jquery',
#   'bash',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'typescript',
#   'express',
#   'docker',
#   'scala',
#   'canvas',
#   'kubernetes'],
#  ['sql'],
#  ['sql', 'php', 'wordpress', 'html', 'javascript', 'scala', 'css'],
#  ['sql', 'rust', 'amazon web services', 'docker', 'kubernetes'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['rust'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['rust', 'javascript'],
#  ['swift', 'javascript', 'objective c', 'c++'],
#  ['sql', 'javascript', 'node', 'amazon web services'],
#  ['react', 'rust', 'amazon web services'],
#  ['amazon web services', 'react', 'javascript', 'node', 'rust'],
#  ['python', 'rust', 'javascript', 'flask'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['sql', 'jquery', 'react', 'html', 'javascript', 'css'],
#  ['postgresql', 'node', 'typescript', 'express', 'docker'],
#  ['python', 'javascript', 'rust', 'swift', 'machine learning'],
#  [],
#  ['vue'],
#  ['react native', 'elixir', 'react', 'html', 'javascript', 'node', 'css'],
#  ['vue',
#   'cordova',
#   'django',
#   'php',
#   'rabbitmq',
#   'html',
#   'javascript',
#   'postgresql',
#   'laravel',
#   'docker'],
#  ['redis',
#   'sql',
#   'amazon web services',
#   'f#',
#   'html',
#   'javascript',
#   'scala',
#   'css'],
#  ['amazon web services', 'f#', 'postgresql', 'javascript', 'scala', 'ruby'],
#  ['python', 'amazon web services', 'django'],
#  ['redis',
#   'graphql',
#   'vue',
#   'react',
#   'postgresql',
#   'node',
#   'typescript',
#   'docker',
#   'nosql'],
#  ['scala'],
#  [],
#  [],
#  [],
#  [],
#  ['amazon web services', 'kotlin', 'java', 'dynamodb', 'rust'],
#  ['docker'],
#  ['python', 'react', 'javascript', 'rust', 'flask'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['sass', 'html', 'javascript', 'docker', 'css'],
#  ['react', 'java', 'javascript', 'react native'],
#  ['python', 'kubernetes', 'amazon web services', 'docker'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['mongodb', 'javascript', 'node', 'vue'],
#  ['react', 'scala', 'spring'],
#  ['rust', 'canvas'],
#  ['sql',
#   'amazon web services',
#   'rust',
#   'scala',
#   'canvas',
#   'nosql',
#   'kubernetes'],
#  [],
#  [],
#  ['java', 'node', 'dynamodb'],
#  [],
#  [],
#  [],
#  ['redis', 'ansible', 'postgresql', 'rabbitmq', 'docker'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['sql',
#   'vue',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'laravel',
#   'angular',
#   'docker',
#   'nosql',
#   'css'],
#  ['sql', 'javascript', 'node', 'docker', 'kubernetes'],
#  ['docker', 'java', 'spring', 'rust', 'kubernetes'],
#  ['sql',
#   'amazon web services',
#   'python',
#   'java',
#   'apache',
#   'scala',
#   'machine learning'],
#  ['python', 'react', 'javascript', 'rust', 'flask'],
#  ['vue',
#   'sass',
#   'django',
#   'react',
#   'javascript',
#   'typescript',
#   'angular',
#   'scala',
#   'css'],
#  [],
#  ['jquery', 'python', 'sass', 'django', 'postgresql', 'javascript', 'scala'],
#  ['graphql',
#   'sql',
#   'python',
#   'php',
#   'react',
#   'html',
#   'javascript',
#   'docker',
#   'css'],
#  ['python', 'html'],
#  ['redis',
#   'elixir',
#   'docker',
#   'python',
#   'golang',
#   'postgresql',
#   'rabbitmq',
#   'rust',
#   'scala',
#   'kubernetes'],
#  ['react', 'javascript', 'shopify', 'typescript', 'graphql', 'css', 'ruby'],
#  ['jquery', 'html', 'javascript', 'angular', 'css'],
#  ['sql'],
#  [],
#  ['rust', 'scala', 'python'],
#  ['python', 'sql', 'google cloud platform', 'amazon web services'],
#  [],
#  ['react', 'sql', 'javascript', 'angular'],
#  ['rust', 'scala'],
#  [],
#  [],
#  ['sql',
#   'ansible',
#   'bash',
#   'python',
#   'google cloud platform',
#   'sass',
#   'php',
#   'wordpress'],
#  ['react', 'html', 'javascript', 'angular', 'css'],
#  ['rust', 'node', 'docker', 'kubernetes', 'shell'],
#  ['python', 'django'],
#  ['rust', 'python'],
#  ['react', 'javascript', 'node', 'angular'],
#  ['redis',
#   'ansible',
#   'vue',
#   'python',
#   'java',
#   'google cloud platform',
#   'sass',
#   'node',
#   'docker',
#   'scala',
#   'flask',
#   'ruby'],
#  ['bash',
#   'docker',
#   'amazon web services',
#   'python',
#   'google cloud platform',
#   'node',
#   'powershell',
#   'kubernetes',
#   'machine learning'],
#  ['react native',
#   'react',
#   'xamarin',
#   'javascript',
#   'html',
#   'typescript',
#   'angular',
#   'rust'],
#  ['sql', 'python', 'html', 'javascript', 'angular', 'machine learning'],
#  ['sql', 'microsoft sql server', 'oracle', 'express'],
#  ['docker', 'node', 'amazon web services', 'dynamodb'],
#  [],
#  ['redis',
#   'sql',
#   'amazon web services',
#   'f#',
#   'html',
#   'javascript',
#   'scala',
#   'css'],
#  ['sql',
#   'jquery',
#   'vue',
#   'java',
#   'react',
#   'javascript',
#   'angular',
#   'scala',
#   'css'],
#  ['sql', 'jquery', 'java', 'javascript', 'scala', 'css'],
#  [],
#  [],
#  ['python', 'sass', 'react', 'html', 'javascript', 'css'],
#  [],
#  ['html', 'javascript', 'vue', 'css'],
#  ['python', 'react', 'javascript', 'node', 'scala', 'nosql', 'flask'],
#  ['redis',
#   'sql',
#   'vue',
#   'google cloud platform',
#   'react',
#   'javascript',
#   'typescript',
#   'angular',
#   'scala',
#   'css'],
#  ['php', 'angular'],
#  [],
#  ['python', 'sql', 'scala', 'shell'],
#  ['sql', 'amazon web services', 'java', 'google cloud platform', 'assembly'],
#  ['rust'],
#  ['rust', 'javascript'],
#  ['react'],
#  [],
#  [],
#  ['sass'],
#  ['react'],
#  ['amazon web services', 'react', 'javascript', 'node', 'rust'],
#  ['sql', 'javascript', 'node', 'amazon web services'],
#  ['react native',
#   'sql',
#   'python',
#   'react',
#   'javascript',
#   'node',
#   'graphql',
#   'apollo'],
#  ['redis', 'sql', 'heroku', 'elasticsearch', 'postgresql', 'ruby'],
#  ['amazon web services', 'python', 'react', 'javascript', 'rust', 'flask'],
#  ['sql', 'amazon web services', 'java', 'spring', 'rust', 'scala', 'nosql'],
#  ['react', 'rust', 'amazon web services'],
#  ['sql',
#   'bash',
#   'cordova',
#   'html',
#   'typescript',
#   'angular',
#   'powershell',
#   'css'],
#  ['swift', 'objective c'],
#  ['shopify', 'laravel'],
#  ['python', 'nosql', 'tensorflow', 'machine learning'],
#  ['xamarin'],
#  ['sql', 'php', 'html', 'javascript', 'css'],
#  [],
#  ['php', 'html', 'javascript', 'angular', 'css'],
#  ['sql', 'amazon web services', 'java', 'sass', 'apache', 'shell'],
#  ['redis',
#   'jquery',
#   'amazon web services',
#   'php',
#   'html',
#   'javascript',
#   'node',
#   'docker',
#   'canvas'],
#  ['scala'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['python', 'bash', 'oracle', 'c++'],
#  ['amazon web services', 'docker', 'scala', 'kubernetes', 'shell'],
#  [],
#  ['react native', 'swift', 'javascript', 'kotlin'],
#  ['redis',
#   'mongodb',
#   'docker',
#   'react',
#   'html',
#   'javascript',
#   'node',
#   'express',
#   'graphql',
#   'kubernetes',
#   'css'],
#  ['sql',
#   'amazon web services',
#   'python',
#   'shopify',
#   'graphql',
#   'flask',
#   'machine learning'],
#  [],
#  ['mongodb', 'javascript', 'node', 'vue'],
#  ['java', 'sass', 'react', 'html', 'javascript', 'css'],
#  ['redis',
#   'sql',
#   'jquery',
#   'amazon web services',
#   'sass',
#   'php',
#   'html',
#   'javascript',
#   'docker',
#   'scala',
#   'css'],
#  ['vue', 'react', 'javascript', 'angular', 'docker', 'css'],
#  ['sql', 'javascript', 'postgresql', 'ruby'],
#  ['sql',
#   'objective c',
#   'amazon web services',
#   'java',
#   'react',
#   'node',
#   'machine learning',
#   'docker',
#   'swift',
#   'kubernetes',
#   'ruby'],
#  ['sql',
#   'mongodb',
#   'amazon web services',
#   'java',
#   'python',
#   'elasticsearch',
#   'rabbitmq',
#   'node',
#   'docker',
#   'kubernetes',
#   'machine learning'],
#  [],
#  [],
#  ['powershell',
#   'ansible',
#   'bash',
#   'amazon web services',
#   'python',
#   'docker',
#   'scala',
#   'kubernetes'],
#  ['amazon web services', 'heroku', 'react', 'kubernetes', 'ruby'],
#  ['ruby'],
#  ...]

# %% [markdown]
# ## Data frame 🙃

# %%
df = pd.DataFrame(titles, columns=['Title'])

df['Link'] = links
df["Languages"] = [",".join(techs) for techs in languages]
df["Web Frameworks"] = [",".join(techs) for techs in web_frameworks]
df["Libraries"] = [",".join(techs) for techs in libraries]
df["Databases"] = [",".join(techs) for techs in databases]
df["Platforms"] = [",".join(techs) for techs in platforms]
df["Other"] = [",".join(techs) for techs in other]
df['Experience Level'] = [level for level in entry_levels_clean]
df
# Out:
#                                                   Title  \
# 0      Senior Systems Administrator (Washington, D.C...
# 1                     Front-End Developer at Wallethub
# 2      Part-Time Full Stack Web Developer with React...
# 3      Full Stack Developer (Remote United States) a...
# 4                                       Medical Biller
# ...                                                 ...
# 1675            .NET Engineer at AdHawk and FloorForce
# 1676      Senior SRE - Master of None at Packet Fabric
# 1677   Senior Big Data Scalability Engineer (Remote ...
# 1678   Customer Service and Sales for Cpap Supplies ...
# 1679   Senior Engineer, Developer Platform (CICD) at...
#
#                                                    Link  \
# 0     https://www.remote.io/job/4048/senior-systems-...
# 1     https://www.remote.io/job/4047/front-end-devel...
# 2     https://www.remote.io/job/4046/part-time-full-...
# 3     https://www.remote.io/job/4045/full-stack-deve...
# 4         https://www.remote.io/job/4044/medical-biller
# ...                                                 ...
# 1675  https://www.remote.io/job/2360/net-engineer-at...
# 1676  https://www.remote.io/job/2357/senior-sre-mast...
# 1677  https://www.remote.io/job/2358/senior-big-data...
# 1678  https://www.remote.io/job/2356/customer-servic...
# 1679  https://www.remote.io/job/2355/senior-engineer...
#
#                                               Languages  \
# 0                                     java,sass,c,shell
# 1                             php,html,javascript,c,css
# 2              bash,sass,html,javascript,shell,css,ruby
# 3                                                  ruby
# 4
# ...                                                 ...
# 1675  asp,sql,php,html,javascript,c#,graphql,c,css,ruby
# 1676                                             python
# 1677                    sql,java,sass,c,golang,scala,go
# 1678
# 1679                                    javascript,ruby
#
#                  Web Frameworks   Libraries                 Databases  \
# 0                                    apache                     mysql
# 1                       angular
# 2                    react,ruby         git                postgresql
# 3                    react,ruby
# 4
# ...                         ...         ...                       ...
# 1675  react,jquery,express,ruby    git,.net      microsoft sql server
# 1676                                ansible  elasticsearch,postgresql
# 1677                             git,apache      redis,dynamodb,mysql
# 1678
# 1679                       ruby                                 mysql
#
#                                   Platforms Other Experience Level
# 0         aws,ios,amazon web services,linux                 senior
# 1                                                            other
# 2                                docker,aws                 senior
# 3                                                            other
# 4                                                            other
# ...                                     ...   ...              ...
# 1675                        microsoft azure                  other
# 1676          aws,amazon web services,linux                  other
# 1677  aws,shopify,amazon web services,linux                 senior
# 1678                                                         other
# 1679   aws,docker,amazon web services,linux                  other
#
# [1680 rows x 9 columns]

# %% [markdown]
# ## Save DataFrame

# %%
df.to_csv('dataframes/remote-io.csv', index = False)

# %% [markdown]
# ## Create a dictionary to count the times a technology is required

# %%
def create_tech_dict(col_name,df):
    technologies_set = df[col_name]
    technologies_dict= {}
    for technologies in technologies_set:
        for technology in technologies.split(','):
            if technology in technologies_dict.keys():
                technologies_dict[technology] += 1
            else:
                technologies_dict[technology] =  1
    return {key: value for key, value in sorted(technologies_dict.items(), key=lambda item: item[1])}

# %%
create_tech_dict('Libraries',df)
# create_tech_dict('Web Frameworks',df)
# create_tech_dict('Languages',df)
# create_tech_dict('Databases',df)
create_tech_dict('Platforms',df)
# create_tech_dict('Other',df)
# Out:
# {'raspberry pi': 3,
#  'ibm cloud': 5,
#  'shopify': 11,
#  'macos': 13,
#  'apollo': 17,
#  'microsoft azure': 19,
#  'rabbitmq': 25,
#  'heroku': 34,
#  'google cloud platform': 37,
#  'wordpress': 38,
#  'android': 71,
#  'slack': 75,
#  'windows': 87,
#  'kubernetes': 136,
#  'ios': 172,
#  'linux': 189,
#  'docker': 195,
#  'amazon web services': 263,
#  'aws': 370,
#  '': 861}

# %% [markdown]
# ## React not invited to the party!
# Here I found out that it's not repeating react when we have react native 🎊

# %%
# react_native_rows = df[df['Technologies'].str.contains('react native')]
# react_native_rows
# Out:
#                                                   Title  \
# 58     UI Lead / Front-End Developer (ReactJS / Reac...
# 66     Mobile Developer - Android/iOS - Freelance at...
# 80     React Native Developer [100% REMOTE] at Cleve...
# 84     Sr. Ruby on Rails and React Native Engineer [...
# 90     Senior React-Native Developer at Avanoo (San ...
# 145    Senior Front End Engineer at Unanet, Inc. (St...
# 168    Senior Mobile Engineer, Flutter at Team Go, Inc
# 170    Hardcore React Native and NodeJs application ...
# 187        Frontend Engineer, React.js at productboard
# 207    React Native Developer [100% REMOTE] at Cleve...
# 208    Sr. Ruby on Rails and React Native Engineer [...
# 229    Senior Full Stack Developer (Ruby/Rails+Elixi...
# 249    UI Lead / Front-End Developer (ReactJS / Reac...
# 330    React Native Developer [100% REMOTE] at Cleve...
# 377    React Native Developer [100% REMOTE] at Cleve...
# 406    Senior Salesforce Commerce Cloud Full Stack D...
# 432    Sr. Software Development Engineer in Test at ...
# 440    Seeking Founding Level CTO - React/Node/React...
# 451    Expert FS NodeJs / React / RN Developer Requi...
# 467    Remote React Native Developer - Solve interes...
# 468    Senior iOS Swift SDK Developer at Rekordio (S...
# 469     React Native Developer at Evertel Technologies
# 525       iOS Developer (f/m/d) – in Hamburg or Remote
# 550    React Native Developer [100% REMOTE] at Cleve...
# 611    React Native Developer [100% REMOTE] at Cleve...
# 691    Remote Senior Full-stack PHP/React/MySQL Deve...
# 715        React/React Native developer at Soshace LLC
# 745    Senior Software Engineer - .NET Core, JS, Azu...
# 870    Senior Frontend Engineer (React) - Community....
# 886    Full-Stack Engineer: Special Projects at Meda...
# 931    Senior React/RN Developer (React, RN, TypeScr...
# 959        React and React native Engineer at Overloop
# 984    Remote Lead React Native Engineer (US/ Canadi...
# 1039             Senior React Developer at DjangoForce
# 1058            Software Engineer in Test at Knock.com
# 1088   Senior Swift Developer at Undefined LLC (Loui...
# 1121   Remote - Senior Software Engineer (Node + AWS...
# 1254   FULL-STACK REACT NATIVE DEVELOPER at Scalable...
# 1260   Senior Full-Stack JavaScript Software Enginee...
# 1261   Senior Front End Developer - React Focused at...
# 1347      Senior Web Development Engineer at Trov Inc.
# 1379                              Mobile App Developer
# 1397                                  Senior Developer
# 1413            Full Stack React Engineer at Brushfire
# 1480     Senior Web Developer at Kukui (Roseville, CA)
# 1611                          Tech Lead at Common Code
# 1620   Mobile Engineer (React Native) at CompanyCam,...
#
#                                                    Link  \
# 58    https://www.remote.io/job/3990/ui-lead-front-e...
# 66    https://www.remote.io/job/3982/mobile-develope...
# 80    https://www.remote.io/job/3968/react-native-de...
# 84    https://www.remote.io/job/3964/sr-ruby-on-rail...
# 90    https://www.remote.io/job/3958/senior-react-na...
# 145   https://www.remote.io/job/3903/senior-front-en...
# 168   https://www.remote.io/job/3880/senior-mobile-e...
# 170   https://www.remote.io/job/3878/hardcore-react-...
# 187   https://www.remote.io/job/3861/frontend-engine...
# 207   https://www.remote.io/job/3841/react-native-de...
# 208   https://www.remote.io/job/3840/sr-ruby-on-rail...
# 229   https://www.remote.io/job/3819/senior-full-sta...
# 249   https://www.remote.io/job/3799/ui-lead-front-e...
# 330   https://www.remote.io/job/3718/react-native-de...
# 377   https://www.remote.io/job/3671/react-native-de...
# 406   https://www.remote.io/job/3642/senior-salesfor...
# 432   https://www.remote.io/job/3618/sr-software-dev...
# 440   https://www.remote.io/job/3608/seeking-foundin...
# 451   https://www.remote.io/job/3597/expert-fs-nodej...
# 467   https://www.remote.io/job/3581/remote-react-na...
# 468   https://www.remote.io/job/3580/senior-ios-swif...
# 469   https://www.remote.io/job/3579/react-native-de...
# 525   https://www.remote.io/job/3523/ios-developer-f...
# 550   https://www.remote.io/job/3498/react-native-de...
# 611   https://www.remote.io/job/3437/react-native-de...
# 691   https://www.remote.io/job/3356/remote-senior-f...
# 715   https://www.remote.io/job/3333/react-react-nat...
# 745   https://www.remote.io/job/3303/senior-software...
# 870   https://www.remote.io/job/3178/senior-frontend...
# 886   https://www.remote.io/job/3162/full-stack-engi...
# 931   https://www.remote.io/job/3116/senior-react-rn...
# 959   https://www.remote.io/job/3082/react-and-react...
# 984   https://www.remote.io/job/3060/remote-lead-rea...
# 1039  https://www.remote.io/job/3005/senior-react-de...
# 1058  https://www.remote.io/job/2983/software-engine...
# 1088  https://www.remote.io/job/2954/senior-swift-de...
# 1121  https://www.remote.io/job/2920/remote-senior-s...
# 1254  https://www.remote.io/job/2782/full-stack-reac...
# 1260  https://www.remote.io/job/2777/senior-full-sta...
# 1261  https://www.remote.io/job/2778/senior-front-en...
# 1347  https://www.remote.io/job/2686/senior-web-deve...
# 1379  https://www.remote.io/job/2655/mobile-app-deve...
# 1397    https://www.remote.io/job/2637/senior-developer
# 1413  https://www.remote.io/job/2620/full-stack-reac...
# 1480  https://www.remote.io/job/2555/senior-web-deve...
# 1611  https://www.remote.io/job/2423/tech-lead-at-co...
# 1620  https://www.remote.io/job/2415/mobile-engineer...
#
#                                            Technologies Experience Level
# 58    react native,amazon web services,python,react,...           senior
# 66            react native,kotlin,cordova,swift,flutter            other
# 80                              react native,react,rust           senior
# 84    react native,sql,redis,heroku,react,postgresql...            other
# 90                                         react native            other
# 145           react native,vue,java,react,angular,scala           senior
# 168   react native,graphql,mongodb,tensorflow,kotlin...           senior
# 170            react native,sql,javascript,node,express            other
# 187   react native,redis,rust,python,react,node,type...           senior
# 207                             react native,react,rust           senior
# 208   react native,sql,redis,heroku,react,postgresql...            other
# 229   react native,elixir,docker,golang,graphql,scal...           senior
# 249   react native,amazon web services,python,react,...           senior
# 330                             react native,react,rust           senior
# 377                             react native,react,rust           senior
# 406                                        react native           senior
# 432   react native,sql,html,javascript,node,docker,k...           senior
# 440        react native,kotlin,react,node,express,swift            other
# 451    react native,react,javascript,node,express,nosql            other
# 467                  react,javascript,react native,node            other
# 468    react native,javascript,node,express,swift,nosql            other
# 469      react native,objective c,java,javascript,swift            other
# 525        react native,objective c,react,graphql,swift            other
# 550                             react native,react,rust           senior
# 611                             react native,react,rust           senior
# 691   react native,sql,sass,php,react,elasticsearch,...           senior
# 715                  react,javascript,react native,node            other
# 745   redis,sql,jquery,react native,html,javascript,...           senior
# 870   react native,elixir,react,html,javascript,node...           senior
# 886                  react,java,javascript,react native            other
# 931   react native,react,xamarin,javascript,html,typ...           senior
# 959   react native,sql,python,react,javascript,node,...            other
# 984                react native,swift,javascript,kotlin            other
# 1039                          react,react native,django            other
# 1058  react native,sql,html,javascript,node,docker,k...           senior
# 1088            react native,react,firebase,swift,nosql           senior
# 1121      react native,react,postgresql,node,typescript           senior
# 1254               react native,php,firebase,scala,ruby            other
# 1260  react native,amazon web services,heroku,react,...            other
# 1261  react native,spring,react,html,javascript,node...           senior
# 1347  react native,react,javascript,node,typescript,...           senior
# 1379     react native,sql,java,python,javascript,oracle           senior
# 1397  react native,sql,python,react,postgresql,javas...           senior
# 1413       react native,sql,react,javascript,node,nosql           senior
# 1480                        rust,react,sql,react native           senior
# 1611           react native,react,javascript,node,scala            other
# 1620  react native,objective c,java,c++,react,graphq...            other
