# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import math

# %% [markdown]
# ## Find the number of pages

# %%
url = 'https://stackoverflow.com/jobs/remote-developer-jobs'

response = requests.get(url)
soup = BeautifulSoup(response.content, features = 'lxml')

jobs_nb = soup.find('div', attrs = {'class':'js-search-title'}).findChild().text
jobs_nb = re.findall('\d+', jobs_nb)[0]

#QUES - Why does the website shop 116 jobs and here I receive 416  🤔

pages = math.ceil((int(jobs_nb)/25))
jobs_nb

soup.find('div', attrs = {'class':'js-search-title'})
# Out:
# <div class="js-search-title -header h4 seo-header">
# <span class="description">
# 416 jobs                </span>
# <span class="description"> | </span><h1 class="h1 description">Remote developer jobs</h1>
# </div>

# %% [markdown]
# ## Set url to scrape list of jobs

# %%
#Erase this line when I find out why I have 17 pages
pages = 7
urls = ['https://stackoverflow.com/jobs/remote-developer-jobs?pg='+ str(page) for page in range(1,pages+1)]

# %%
responses =[requests.get(url) for url in urls]

# %%
soups = [BeautifulSoup(response.content,'lxml') for response in responses]

# %%
a_tags = [soup.find_all('a', {'class':'s-link stretched-link'}) for soup in soups]
titles = [a.text for sublist in a_tags for a in sublist]

# %%
tech_tags = [soup.find_all('a', attrs ={'class': 'post-tag'})]
technologies = [a.text for tag in tech_tags for a in tag]
list(set(technologies))
# Out:
# ['objective-c',
#  'concurrency',
#  'flask',
#  'multithreading',
#  'laravel',
#  'elasticsearch',
#  'heroku',
#  'ruby-on-rails',
#  'gwt',
#  'graphql',
#  'network-programming',
#  'google-cloud-platform',
#  'java',
#  'python',
#  'user-interface',
#  'swift',
#  'gwtp',
#  'mysql',
#  'shopify',
#  'distributed-computing',
#  'node.js',
#  '.net',
#  'hibernate',
#  'ansible',
#  'sysadmin',
#  'firebase',
#  'php',
#  'kafka',
#  'ios',
#  'docker',
#  'flash',
#  'c#',
#  'c++',
#  'performance-testing',
#  'airflow',
#  'aws',
#  'go',
#  'secure-coding',
#  'postgresql',
#  'testing',
#  'golang',
#  'computer-science',
#  'javascript',
#  'distributed-system',
#  'sass',
#  'googletest',
#  'enterprise',
#  'cryptocurrency',
#  'react',
#  'angular',
#  'macos',
#  'xcode',
#  'mobile',
#  'nosql',
#  'typescript',
#  'spring-boot',
#  'continuous-integration',
#  'data-structures',
#  'next.js',
#  'devops',
#  'automation',
#  'reactjs',
#  'chromium',
#  'kotlin',
#  'actionscript-3',
#  'amazon-web-services',
#  'linux',
#  'html5',
#  'mongodb',
#  'algorithm',
#  'asp.net-core',
#  'time-complexity']

# %%
links = ['https://stackoverflow.com' + a['href'] for sublist in a_tags for a in sublist]

# %% [markdown]
# ## DataFrame 🙃

# %%
df = pd.DataFrame(titles,columns = ["Title"])
df['Link'] = links
df
# Out:
#                                                  Title  \
# 0                                      DevOps Engineer
# 1                       ActionScript / FLASH Developer
# 2    Mid to Senior Front End Developer - $75K to $1...
# 3                    Senior Python Engineer in Fintech
# 4    Computer Science Eng. to Brainstorm Topics for...
# ..                                                 ...
# 170                     Senior Linux Software Engineer
# 171                                  Software Engineer
# 172  Elixir/API Engineer with Growing Messaging Com...
# 173             Senior Software Engineer - Big Data/AI
# 174                                  Android Developer
#
#                                                   Link
# 0    https://stackoverflow.com/jobs/378945/devops-e...
# 1    https://stackoverflow.com/jobs/379299/actionsc...
# 2    https://stackoverflow.com/jobs/358552/mid-to-s...
# 3    https://stackoverflow.com/jobs/334701/senior-p...
# 4    https://stackoverflow.com/jobs/350799/computer...
# ..                                                 ...
# 170  https://stackoverflow.com/jobs/367261/senior-l...
# 171  https://stackoverflow.com/jobs/367258/software...
# 172  https://stackoverflow.com/jobs/335070/elixir-a...
# 173  https://stackoverflow.com/jobs/342960/senior-s...
# 174  https://stackoverflow.com/jobs/173378/android-...
#
# [175 rows x 2 columns]

# %% [markdown]
# ## Set url for scraping the job descriptions

# %%
description_responses =[requests.get(url) for url in links]

# %%
description_soups = [BeautifulSoup(response.content,'lxml') for response in description_responses]

# %% [markdown]
# **Tech tags**:

# %%
tags = [soup.find_all('a', attrs = {'class':'post-tag'}) for soup in description_soups]

# %% [markdown]
# **Job Details**:

# %%
job_details = [soup.find_all('div', attrs = {'class':'job-details--about'}) for soup in description_soups]

job_det = []

for job in job_details:
    if len(job):
        if len(job[0].find_all('span')) > 2:
            job_det.append([job[0].find_all('span')[3].text.lower()])
        else:
            job_det.append(['other'])  
    else:
        job_det.append(['other'])

job_det
# Out:
# [['mid-level, senior'],
#  ['senior'],
#  ['junior, mid-level, senior'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['manager'],
#  ['mid-level, senior'],
#  ['lead, manager'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['other'],
#  ['senior'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior'],
#  ['senior, lead'],
#  ['backend developer'],
#  ['mid-level, senior'],
#  ['senior'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level'],
#  ['senior'],
#  ['senior'],
#  ['senior'],
#  ['senior'],
#  ['mid-level, senior'],
#  ['lead'],
#  ['mid-level, senior'],
#  ['lead'],
#  ['senior, lead'],
#  ['senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['frontend developer'],
#  ['mid-level'],
#  ['senior, lead'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['other'],
#  ['other'],
#  ['information technology, software development, software development / engineering'],
#  ['senior, lead'],
#  ['junior, mid-level, senior'],
#  ['senior'],
#  ['mid-level'],
#  ['senior'],
#  ['mid-level, senior'],
#  ['senior'],
#  ['senior, lead'],
#  ['other'],
#  ['junior, mid-level'],
#  ['junior, mid-level'],
#  ['lead, manager'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['senior'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['junior, mid-level'],
#  ['senior'],
#  ['senior'],
#  ['junior, mid-level, senior'],
#  ['junior, mid-level, senior'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['manager'],
#  ['backend developer'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['senior'],
#  ['backend developer'],
#  ['backend developer, data scientist'],
#  ['data scientist'],
#  ['devops'],
#  ['mid-level, senior, lead'],
#  ['senior, lead, manager'],
#  ['junior, mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['junior, mid-level'],
#  ['mid-level'],
#  ['senior, lead'],
#  ['senior'],
#  ['other'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['senior, lead, manager'],
#  ['senior, lead'],
#  ['senior'],
#  ['senior'],
#  ['mid-level, senior'],
#  ['senior, lead, manager'],
#  ['senior'],
#  ['senior'],
#  ['mid-level'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior'],
#  ['mid-level'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['junior, mid-level, senior'],
#  ['senior'],
#  ['mid-level, senior'],
#  ['mid-level, senior'],
#  ['mid-level'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['mid-level'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['senior'],
#  ['senior'],
#  ['senior'],
#  ['information technology, speech recognition'],
#  ['mid-level, senior, lead'],
#  ['other'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['senior, lead'],
#  ['senior, lead'],
#  ['devops, system administrator'],
#  ['mid-level, senior'],
#  ['mid-level, senior, lead'],
#  ['mid-level, senior, lead'],
#  ['junior, mid-level, senior'],
#  ['mid-level, senior'],
#  ['manager'],
#  ['mid-level'],
#  ['senior'],
#  ['backend developer'],
#  ['mid-level, senior, lead'],
#  ['senior, lead'],
#  ['junior, mid-level'],
#  ['other'],
#  ['junior, mid-level, senior'],
#  ['senior'],
#  ['mid-level'],
#  ['senior, lead'],
#  ['mid-level, senior'],
#  ['junior'],
#  ['senior'],
#  ['junior, mid-level'],
#  ['senior, lead'],
#  ['senior'],
#  ['mid-level'],
#  ['mid-level, senior'],
#  ['senior'],
#  ['mid-level, senior']]

# %% [markdown]
# ## Find technologies in golden source

# %%
technologies = pd.read_json('golden-source-data.json')
word_boundary_techs = r'\b|\b'.join(technologies['remote_jobs']['word_boundary_techs'])
no_boundary_techs = "|".join(technologies['remote_jobs']['no_boundary_techs'])
pattern = word_boundary_techs + "|" + no_boundary_techs+ '|c\+\+'
# pattern.replace('\x08', '')
pattern
# Out:
# 'aws\\b|\\bgo\\b|\\bgit\\b|\\bux\\b|\\bui\\b|\\bseo\\b|\\bC#\\b|\\br\\b|\\bc\\b|\\bc#\\b|\\basp\\b|\\bvba|docker|rabbitmq|html|express|php|spring|css|react bootstrap|react native|react|vue|javascript|java|node|ruby|python|typescript|graphql|mongodb|redis|orchardcms|machine learning|umbraco|canvas|angular|django|google cloud platform|kotlin|swift|matlab|rust|golang|bash|powershell|shell|f#|scala|clojure|elixir|webassembly|assembly|objective c|dart|jquery|flask|laravel|drupal|pandas|tensorflow|ansible|cordova|xamarin|apache|hadoop|unreal engine|flutter|puppet|cryengine|mariadb|headoop|oracle|elasticsearch|firebase|dynamodb|cassandra|couchbase|microsoft sql server|postgresql|sql|nosql|apollo|wordpress|heroku|kubernetes|amazon web services|chromium|pytorch|sass|shopify|c\\+\\+'

# %%
tech_tags = [list(set(re.findall(pattern,str(tag).replace("-"," ").lower()))) for tag in tags]
tech_tags
# Out:
# [['java', 'ansible', 'docker', 'mongodb', 'amazon web services', 'apache'],
#  ['oracle', 'react', 'angular', 'graphql', 'javascript'],
#  ['shopify', 'laravel'],
#  ['machine learning',
#   'flask',
#   'pandas',
#   'apache',
#   'docker',
#   'sql',
#   'amazon web services',
#   'google cloud platform',
#   'python'],
#  ['scala', 'java'],
#  ['typescript', 'react', 'kotlin', 'graphql', 'postgresql'],
#  ['java'],
#  ['java'],
#  ['golang',
#   'vue',
#   'react',
#   'ruby',
#   'angular',
#   'tensorflow',
#   'pytorch',
#   'pandas',
#   'amazon web services',
#   'java',
#   'python'],
#  ['angular', 'docker', 'mongodb', 'amazon web services', 'python'],
#  ['angular', 'docker', 'mongodb', 'amazon web services', 'python'],
#  ['angular'],
#  [],
#  [],
#  ['shopify', 'sass', 'firebase', 'react', 'nosql', 'swift'],
#  ['shopify', 'sass', 'firebase', 'react', 'nosql', 'swift'],
#  ['amazon web services', 'java'],
#  ['jquery', 'react', 'angular', 'node', 'javascript'],
#  ['react',
#   'elasticsearch',
#   'hadoop',
#   'wordpress',
#   'amazon web services',
#   'sql',
#   'python',
#   'javascript'],
#  ['objective c', 'swift'],
#  ['sql', 'javascript', 'angular', 'java'],
#  ['react', 'heroku', 'ruby'],
#  ['sql', 'java'],
#  ['laravel', 'sql', 'react', 'javascript'],
#  ['chromium',
#   'javascript',
#   'rust',
#   'c++',
#   'amazon web services',
#   'node',
#   'postgresql'],
#  ['kubernetes', 'machine learning', 'flask', 'pytorch', 'sql', 'python'],
#  ['amazon web services'],
#  ['clojure',
#   'ruby',
#   'docker',
#   'scala',
#   'amazon web services',
#   'sql',
#   'javascript'],
#  ['oracle', 'react', 'angular', 'graphql', 'javascript'],
#  ['sql', 'react', 'python', 'kubernetes'],
#  ['typescript',
#   'kubernetes',
#   'bash',
#   'amazon web services',
#   'node',
#   'javascript'],
#  ['react', 'docker', 'java', 'sql', 'javascript'],
#  ['react'],
#  ['amazon web services', 'shell'],
#  ['node', 'sql', 'python', 'angular'],
#  ['javascript', 'kubernetes', 'java'],
#  ['xamarin', 'angular', 'javascript'],
#  ['docker', 'kubernetes', 'amazon web services'],
#  ['docker', 'kubernetes', 'amazon web services'],
#  ['react', 'java', 'kubernetes', 'javascript'],
#  ['react', 'node', 'mongodb', 'javascript'],
#  ['google cloud platform'],
#  ['vue', 'react', 'ruby'],
#  [],
#  ['kubernetes', 'machine learning', 'flask', 'pytorch', 'sql', 'python'],
#  ['elasticsearch', 'scala', 'java', 'apache', 'python'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'java',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['ruby'],
#  ['python',
#   'kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  ['kubernetes',
#   'react native',
#   'react',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'sql',
#   'node',
#   'javascript'],
#  [],
#  [],
#  ['xamarin', 'angular', 'javascript'],
#  ['xamarin', 'angular', 'javascript'],
#  ['python', 'react', 'elasticsearch', 'docker', 'sql', 'node', 'javascript'],
#  ['swift'],
#  ['react', 'sass', 'javascript'],
#  ['react native'],
#  ['python', 'sql', 'node', 'angular'],
#  ['typescript', 'amazon web services'],
#  ['typescript', 'amazon web services'],
#  [],
#  ['apache', 'python'],
#  ['python', 'react', 'elasticsearch', 'docker', 'sql', 'node', 'javascript'],
#  ['postgresql',
#   'react',
#   'angular',
#   'docker',
#   'react bootstrap',
#   'amazon web services',
#   'node',
#   'javascript'],
#  [],
#  ['umbraco', 'sql', 'orchardcms', 'javascript'],
#  ['react',
#   'amazon web services',
#   'java',
#   'sql',
#   'node',
#   'swift',
#   'javascript'],
#  ['typescript',
#   'postgresql',
#   'vue',
#   'kubernetes',
#   'django',
#   'flask',
#   'react',
#   'angular',
#   'docker',
#   'mongodb',
#   'amazon web services',
#   'python',
#   'javascript'],
#  ['canvas', 'node', 'react', 'amazon web services'],
#  ['kubernetes',
#   'elasticsearch',
#   'docker',
#   'amazon web services',
#   'java',
#   'nosql',
#   'javascript'],
#  ['kubernetes',
#   'elasticsearch',
#   'docker',
#   'amazon web services',
#   'java',
#   'nosql',
#   'javascript'],
#  ['python', 'machine learning', 'java', 'kotlin'],
#  ['python', 'java', 'machine learning', 'kotlin'],
#  [],
#  ['typescript', 'vue', 'react', 'angular', 'node'],
#  ['vue',
#   'typescript',
#   'kubernetes',
#   'django',
#   'flask',
#   'react native',
#   'react',
#   'angular',
#   'node',
#   'docker',
#   'flutter',
#   'amazon web services',
#   'python',
#   'javascript'],
#  ['react', 'javascript'],
#  ['react', 'amazon web services', 'javascript'],
#  ['typescript', 'react', 'graphql'],
#  ['google cloud platform', 'python', 'kubernetes'],
#  ['javascript'],
#  ['pytorch', 'python', 'kubernetes', 'docker'],
#  ['amazon web services', 'shell'],
#  ['oracle', 'sql', 'angular', 'java'],
#  ['react',
#   'amazon web services',
#   'java',
#   'sql',
#   'node',
#   'swift',
#   'javascript'],
#  ['machine learning',
#   'apache',
#   'amazon web services',
#   'java',
#   'sql',
#   'python'],
#  ['machine learning',
#   'apache',
#   'amazon web services',
#   'java',
#   'sql',
#   'python'],
#  ['machine learning',
#   'apache',
#   'amazon web services',
#   'java',
#   'sql',
#   'python'],
#  ['machine learning',
#   'apache',
#   'amazon web services',
#   'java',
#   'sql',
#   'python'],
#  ['docker', 'sql', 'drupal', 'amazon web services'],
#  ['angular', 'docker', 'mongodb', 'amazon web services', 'python'],
#  ['apache', 'kubernetes', 'java'],
#  ['typescript',
#   'vue',
#   'kubernetes',
#   'django',
#   'flask',
#   'react native',
#   'react',
#   'angular',
#   'node',
#   'docker',
#   'flutter',
#   'amazon web services',
#   'python',
#   'javascript'],
#  ['kubernetes',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'google cloud platform',
#   'python'],
#  ['python',
#   'vue',
#   'laravel',
#   'react',
#   'angular',
#   'docker',
#   'c++',
#   'wordpress',
#   'mongodb',
#   'amazon web services',
#   'node',
#   'javascript'],
#  ['typescript', 'amazon web services'],
#  ['golang',
#   'python',
#   'java',
#   'react',
#   'laravel',
#   'wordpress',
#   'mongodb',
#   'amazon web services',
#   'node',
#   'postgresql'],
#  [],
#  ['golang',
#   'node',
#   'react',
#   'laravel',
#   'wordpress',
#   'mongodb',
#   'java',
#   'amazon web services',
#   'python',
#   'postgresql'],
#  ['xamarin', 'react', 'javascript', 'nosql', 'postgresql'],
#  [],
#  ['kubernetes'],
#  ['kubernetes',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'google cloud platform',
#   'python'],
#  ['kubernetes',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'google cloud platform',
#   'python'],
#  ['shopify', 'sql', 'react', 'javascript'],
#  ['google cloud platform'],
#  [],
#  ['machine learning', 'ruby', 'javascript'],
#  ['docker', 'kubernetes', 'amazon web services', 'java'],
#  ['vue', 'react', 'angular', 'java'],
#  ['vue',
#   'typescript',
#   'kubernetes',
#   'django',
#   'flask',
#   'react',
#   'javascript',
#   'angular',
#   'docker',
#   'mongodb',
#   'amazon web services',
#   'python',
#   'postgresql'],
#  ['hadoop',
#   'ruby',
#   'amazon web services',
#   'java',
#   'apache',
#   'python',
#   'javascript'],
#  ['kubernetes', 'ansible'],
#  ['python', 'java'],
#  ['vue',
#   'typescript',
#   'kubernetes',
#   'objective c',
#   'django',
#   'flask',
#   'react native',
#   'react',
#   'angular',
#   'docker',
#   'flutter',
#   'amazon web services',
#   'python',
#   'swift',
#   'javascript'],
#  ['vue',
#   'typescript',
#   'kubernetes',
#   'django',
#   'flask',
#   'react native',
#   'react',
#   'laravel',
#   'angular',
#   'docker',
#   'flutter',
#   'amazon web services',
#   'sql',
#   'python',
#   'javascript'],
#  [],
#  ['postgresql', 'angular', 'ruby', 'javascript'],
#  ['xamarin', 'react', 'javascript', 'nosql', 'postgresql'],
#  ['docker'],
#  ['golang',
#   'python',
#   'java',
#   'react',
#   'laravel',
#   'wordpress',
#   'mongodb',
#   'amazon web services',
#   'node',
#   'postgresql'],
#  ['machine learning', 'react', 'pytorch', 'python', 'javascript'],
#  ['python', 'java'],
#  ['react', 'python', 'javascript'],
#  ['machine learning', 'kubernetes', 'java'],
#  ['vue',
#   'typescript',
#   'kubernetes',
#   'django',
#   'flask',
#   'react native',
#   'react',
#   'angular',
#   'node',
#   'docker',
#   'flutter',
#   'amazon web services',
#   'python',
#   'javascript'],
#  ['kubernetes',
#   'elasticsearch',
#   'docker',
#   'amazon web services',
#   'java',
#   'nosql',
#   'javascript'],
#  ['dart', 'flutter'],
#  ['docker', 'sql', 'python', 'angular'],
#  ['react native', 'react', 'sql', 'node', 'javascript'],
#  ['python', 'sql', 'wordpress', 'amazon web services'],
#  ['javascript'],
#  ['amazon web services', 'java'],
#  ['amazon web services', 'java'],
#  ['typescript',
#   'kubernetes',
#   'node',
#   'sql',
#   'amazon web services',
#   'apache',
#   'python',
#   'javascript'],
#  ['kotlin', 'c++', 'javascript', 'java'],
#  ['scala', 'java'],
#  ['vue',
#   'typescript',
#   'machine learning',
#   'kubernetes',
#   'django',
#   'flask',
#   'node',
#   'react',
#   'angular',
#   'react native',
#   'docker',
#   'flutter',
#   'amazon web services',
#   'python',
#   'javascript'],
#  ['react',
#   'elasticsearch',
#   'javascript',
#   'amazon web services',
#   'python',
#   'postgresql'],
#  ['react',
#   'elasticsearch',
#   'javascript',
#   'amazon web services',
#   'python',
#   'postgresql'],
#  ['react',
#   'elasticsearch',
#   'javascript',
#   'amazon web services',
#   'python',
#   'postgresql'],
#  ['react', 'javascript'],
#  ['javascript'],
#  ['django', 'flask', 'react', 'sql', 'python'],
#  [],
#  ['ruby', 'amazon web services', 'postgresql'],
#  ['docker', 'flask', 'python', 'ansible'],
#  ['golang',
#   'python',
#   'java',
#   'react',
#   'laravel',
#   'wordpress',
#   'mongodb',
#   'amazon web services',
#   'node',
#   'postgresql'],
#  ['vue', 'react', 'angular', 'java'],
#  [],
#  ['angular', 'javascript', 'java'],
#  [],
#  ['node', 'angular', 'mongodb', 'javascript'],
#  [],
#  ['python', 'react', 'elasticsearch', 'docker', 'sql', 'node', 'javascript'],
#  ['python', 'machine learning', 'amazon web services', 'kotlin'],
#  ['python', 'machine learning', 'amazon web services', 'kotlin'],
#  ['node', 'mongodb'],
#  ['docker', 'kubernetes', 'amazon web services'],
#  ['sql', 'angular', 'ansible', 'javascript'],
#  ['kubernetes',
#   'ruby',
#   'docker',
#   'amazon web services',
#   'google cloud platform',
#   'python'],
#  [],
#  ['react', 'ruby', 'postgresql'],
#  ['sql', 'c++', 'javascript'],
#  ['sql', 'c++', 'javascript'],
#  ['graphql', 'elixir', 'postgresql'],
#  ['python', 'java'],
#  ['sql', 'kotlin', 'java']]

# %% [markdown]
# ## The following code is just used to compare the original technologies in the tags and to compare with the ones found with the pattern.

# %%
description_technologies = []
for a in tags:
    description_technologies.append(','.join([i.text.replace("-"," ") for i in a]))
    
description_technologies
# Out:
# ['linux,ansible,amazon web services,continuous integration,docker,sysadmin,go,web scraping,amazon web services,mongodb,apache kafka,.net,java',
#  'html5,user interface,flash,actionscript 3,angularjs,javascript,reactjs,graphql,css,oracle',
#  'laravel,shopify,laravel',
#  'python,amazon web services,flask,docker,google cloud platform,python,apache,amazon web services,etl,pandas,python,testing,automated tests,continuous integration,unit testing,python,machine learning,pandas,sql,docker,python,machine learning,artificial intelligence,docker,data science',
#  'computer science,algorithm,time complexity,data structures,spring,spring security,spring boot,java,scala,akka',
#  'typescript,reactjs,graphql,kotlin,postgresql',
#  'java,distributed computing,multithreading,network programming,concurrency,testing,distributed system,automation,performance testing',
#  'testing,distributed system,automation,performance testing,java,distributed computing,multithreading,network programming,concurrency',
#  'ruby on rails,java,golang,python,aws,java,python,api,react redux,vue.js,angular,python,amazon web services,tensorflow,keras,pytorch,sklearn pandas,numpy,ios,android,mobile',
#  'go,amazon web services,docker,mongodb,go,angular,amazon web services,devops,mongodb,go,angular,amazon web services,docker,python',
#  'go,angular,amazon web services,devops,mongodb,go,amazon web services,docker,mongodb,go,angular,amazon web services,docker,python',
#  '.net,c#,angular',
#  'c#,asp.net core',
#  '',
#  'swift,ios,firebase,mobile,nosql,reactjs,firebase,sass,next.js,shopify',
#  'reactjs,firebase,sass,next.js,shopify,swift,ios,firebase,mobile,nosql',
#  'java,spring boot,enterprise,amazon web services,secure coding,testing,qa,automation,security,agile',
#  '.net,javascript,angular,node.js,reactjs,c#,.net,asp.net,jquery,angularjs,node.js,reactjs,testing,automated tests,qa',
#  'elasticsearch,php,mysql,kafka,airflow,php,mysql,wordpress,reactjs,javascript,php,python,sql,hadoop,amazon web services',
#  'objective c,ios,swift,xcode,macos',
#  'angular,java,go,javascript,mysql',
#  'ruby on rails,heroku,react',
#  'gwt,gwtp,mysql,hibernate,java',
#  'php,javascript,reactjs,javascript,automation,google chrome extension,php,reactjs,mysql,laravel,javascript',
#  'c++,chromium,javascript,googletest,cryptocurrency,node.js,javascript,postgresql,amazon web services,rust',
#  'go,kubernetes,kubebuilder,containers,python,flask,sqlalchemy,rest,kubernetes,machine learning,python,pytorch,mathematical optimization,kubernetes',
#  'azure,amazon web services,office365,azure active directory,linux,sysadmin',
#  'cloud,security,sysadmin,.net,c#,javascript,sql,html,scala,clojure,ruby,haskell,erlang,c#,.net,sql server,html,css,c#,ruby on rails,ruby,amazon web services,docker',
#  'oracle,angularjs,javascript,reactjs,graphql,css,html5,user interface,flash,actionscript 3',
#  'design,devops,kubernetes,azure kubernetes,git,testing,automated tests,robotframework,python,selenium,reactjs,sql,web services,powerapps,office365',
#  'amazon web services,node.js,php,javascript,jenkins,terraform,kubernetes,typescript,jenkins,bash',
#  'rest,reactjs,java,spring,javascript,java,spring,gradle,docker,sql server',
#  'reactjs,react redux,user interface,jenkins,json',
#  'shell,linux,amazon web services,unix,sysadmin,qa,testing,manual testing',
#  'php,python,sql,security,automated tests,php,node.js,angular,python,github',
#  'microservices,kubernetes,spring boot,java,javascript',
#  'javascript,css,html,angular,c#,c#,.net,angular,azure,selenium,c#,automation,qa,c#,.net,xamarin,xamarin.forms',
#  'qa,testing,automation,terraform,amazon web services,kubernetes,docker',
#  'terraform,amazon web services,kubernetes,docker,qa,testing,automation',
#  'javascript,java,kubernetes,jhipster,reactjs',
#  'javascript,html,node.js,mongodb,reactjs',
#  'google cloud platform,gsuite,google admin sdk,google iam,cloud,ibm cloud,azure devops,on prem,azure,admin,user management,device manager,ou,cloud,linux',
#  'ruby on rails,reactjs,ruby,vue.js',
#  'user experience,user interface,design',
#  'python,flask,sqlalchemy,rest,kubernetes,go,kubernetes,kubebuilder,containers,machine learning,python,pytorch,mathematical optimization,kubernetes',
#  'java,scala,go,elasticsearch,apache spark,python,go,networking,ipv6,dns',
#  'java,spring,java ee,amazon web services,sql,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript',
#  'ruby on rails,reactjs,ruby,sql,javascript,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,mobile,android,ios,ionic2,ionic framework',
#  'amazon web services,jenkins,docker,devops,kubernetes,reactjs,javascript,node.js,express,sql,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript,mobile,android,ios,ionic2,ionic framework',
#  'mobile,android,ios,ionic2,ionic framework,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript',
#  '.net,chef,ruby,c#,dsc',
#  'sql,python,etl,database,bigdata,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript',
#  'reactjs,android,ios,react native,mobile,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,ruby on rails,reactjs,ruby,sql,javascript,mobile,android,ios,ionic2,ionic framework',
#  'reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript,mobile,android,ios,ionic2,ionic framework',
#  'reactjs,three.js,webgl,3d,javascript,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript,mobile,android,ios,ionic2,ionic framework',
#  'amazon web services,jenkins,docker,devops,linux,reactjs,javascript,node.js,express,sql,amazon web services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react native,mobile,ruby on rails,reactjs,ruby,sql,javascript',
#  '',
#  '',
#  'c#,.net,angular,azure,javascript,css,html,angular,c#,selenium,c#,automation,qa,c#,.net,xamarin,xamarin.forms',
#  'c#,.net,xamarin,xamarin.forms,c#,.net,angular,azure,javascript,css,html,angular,c#,selenium,c#,automation,qa',
#  'python,reactjs,javascript,node.js,css,api,docker,gitlab,elasticsearch,logstash,php,symfony,mysql,typo3,extbase,excel,ms access,ms office,ms word,outlook,php,android,symfony',
#  'ios,swift',
#  'javascript,react redux,sass,babeljs,webpack',
#  'react native,rest,ios,android',
#  'php,node.js,angular,python,github,php,python,sql,security,automated tests',
#  'typescript,knockout.js,c#,leaflet,google maps,single page application,c#,amazon web services,typescript,.net,c#,api,typescript,amazon web services,geolocation',
#  'c#,api,typescript,amazon web services,geolocation,single page application,c#,amazon web services,typescript,.net,typescript,knockout.js,c#,leaflet,google maps',
#  'devops,php,linux',
#  'linux,web services,linux,tomcat,apache,python',
#  'php,android,symfony,reactjs,javascript,node.js,css,api,docker,gitlab,elasticsearch,logstash,php,symfony,mysql,typo3,extbase,python,excel,ms access,ms office,ms word,outlook',
#  'amazon web services,angular,react bootstrap,node.js,docker,amazon web services,angularjs,javascript,postgresql,reactjs',
#  'apex,salesforce lightning,salesforce,aura framework,salesforce communities',
#  'episerver,umbraco,sitecore,dotnetnuke,orchardcms,asp.net,c#,tsql,javascript,sql,user interface,user experience,web accessibility',
#  'ios,swift,sdk,java,reactjs,javascript,node.js,npm,tdd,nightwatch.js,jenkins,automation,selenium,javascript,amazon web services,devops,amazon rds,sql',
#  'reactjs,javascript,typescript,babel,cypress,python,postgres,mongodb,flask,django,python,postgresql,flask,cherrypy,mongodb,python,flask,mongodb,javascript,reactjs,angular,angularjs,vue.js,kubernetes,amazon web services,python,docker,splunk',
#  'reactjs,node.js,html5 canvas,seo,amazon web services',
#  'amazon web services,linux,kubernetes,docker,jenkins,sysadmin,java,javascript,kubernetes,elasticsearch,nosql,java,javascript,kubernetes,elasticsearch,nosql',
#  'java,javascript,kubernetes,elasticsearch,nosql,java,javascript,kubernetes,elasticsearch,nosql,amazon web services,linux,kubernetes,docker,jenkins,sysadmin',
#  'algorithm,python,machine learning,kotlin,java,spring,spinnaker',
#  'kotlin,java,spring,spinnaker,algorithm,python,machine learning',
#  'c#,excel,math,quantitative finance,finance',
#  'reactjs,angularjs,node.js,typescript,vue.js',
#  'python,django,flask,javascript,vue.js,reactjs,angular,react native,flutter,javascript,ios,android,reactjs,react redux,typescript,javascript,webpack,devops,amazon web services,docker,kubernetes,node.js,javascript,express',
#  'reactjs,agile,javascript',
#  'javascript,reactjs,amazon web services',
#  'typescript,reactjs,graphql',
#  'google cloud platform,kubernetes,python,azure',
#  'c#,asp.net,.net core,javascript',
#  'python,scikit learn,pytorch,docker,kubernetes',
#  'qa,testing,manual testing,shell,linux,amazon web services,unix,sysadmin',
#  'web services,salesforce,apex,java,sql,java ee,angularjs,hibernate,sfdc,apex,visualforce,b2b,xml,soap,salesforce,apex,visualforce,spring,java,oracle,guidewire,java,java ee,sql',
#  'amazon web services,devops,amazon rds,sql,reactjs,javascript,node.js,npm,tdd,nightwatch.js,jenkins,automation,selenium,javascript,ios,swift,sdk,java',
#  'apache,machine learning,algorithm,r,python,machine learning,data science,statistics,java,spring,jakarta ee,rest,sql,amazon web services,automation,sql,machine learning,python,statistics,business intelligence',
#  'sql,machine learning,python,statistics,business intelligence,r,python,machine learning,data science,statistics,java,spring,jakarta ee,rest,sql,apache,machine learning,algorithm,amazon web services,automation',
#  'r,python,machine learning,data science,statistics,java,spring,jakarta ee,rest,sql,apache,machine learning,algorithm,amazon web services,automation,sql,machine learning,python,statistics,business intelligence',
#  'amazon web services,automation,r,python,machine learning,data science,statistics,java,spring,jakarta ee,rest,sql,apache,machine learning,algorithm,sql,machine learning,python,statistics,business intelligence',
#  'mysql,php,amazon web services,docker,varnish,drupal,scoping',
#  'go,angular,amazon web services,docker,python,go,amazon web services,docker,mongodb,go,angular,amazon web services,devops,mongodb',
#  'apache flink,java,java,apache flink,flink streaming,kubernetes',
#  'reactjs,react redux,typescript,javascript,webpack,javascript,vue.js,reactjs,angular,python,django,flask,react native,flutter,javascript,ios,android,devops,amazon web services,docker,kubernetes,node.js,javascript,express',
#  'amazon web services,python,ruby,amazon web services,ruby,tdd,python,ruby,docker,amazon web services,configuration management,cloud,kubernetes,api design,google cloud platform,hashicorp vault',
#  'c,python,c++,php,javascript,laravel,node.js,reactjs,node.js,mongodb,amazon web services,reactjs,docker,javascript,html,css,vuejs,angular,sysadmin,reactjs,javascript,vue.js,html,css,php,javascript,wordpress,html,css,sysadmin',
#  'single page application,c#,amazon web services,typescript,.net,c#,api,typescript,amazon web services,geolocation,typescript,knockout.js,c#,leaflet,google maps',
#  'reactjs,node.js,web services,salesforce,zendesk,node.js,security,postgresql,amazon web services,postgresql,mongodb,golang,python,java,saml,oauth,openid connect,php,continuous integration,wordpress,node.js,laravel',
#  '',
#  'postgresql,mongodb,golang,python,java,node.js,security,postgresql,amazon web services,reactjs,node.js,web services,salesforce,zendesk,saml,oauth,openid connect,php,continuous integration,wordpress,node.js,laravel',
#  'reactjs,javascript,postgresql,nosql,project management,product management,qa,c#,android,ios,git,xamarin',
#  'windows services,wpf,grpc,com,wcf',
#  'c#,asp.net,blazor,azure,kubernetes',
#  'cloud,kubernetes,api design,google cloud platform,hashicorp vault,amazon web services,ruby,tdd,python,ruby,docker,amazon web services,configuration management,amazon web services,python,ruby',
#  'amazon web services,ruby,tdd,python,ruby,docker,amazon web services,configuration management,cloud,kubernetes,api design,google cloud platform,hashicorp vault,amazon web services,python,ruby',
#  'javascript,shopify,reactjs,liquid,html,asp.net,javascript,c#,vb.net,.net,asp.net,c#,sql server,html5,ajax',
#  'admin,user management,device manager,ou,cloud,google cloud platform,gsuite,google admin sdk,google iam,cloud,ibm cloud,azure devops,on prem,azure,linux',
#  'api,c#,.net',
#  'ruby,machine learning,etl,amazon redshift,javascript',
#  'java,spring boot,hibernate,amazon web services,activemq,amazon web services,kubernetes,docker,terraform,linux',
#  'reactjs,angularjs,vue.js,frontend,web applications,java,api,rest,microservices,web applications,agile,product management,saas,web applications,erp',
#  'python,postgresql,flask,cherrypy,mongodb,python,postgres,mongodb,flask,django,python,flask,mongodb,javascript,reactjs,angular,angularjs,vue.js,reactjs,javascript,typescript,babel,cypress,kubernetes,amazon web services,python,docker,splunk',
#  'amazon web services,java,apache spark,hadoop,hbase,python,security,ruby,java,javascript,security,python,ruby,java,javascript',
#  'ansible,kubernetes,sysadmin,devops',
#  'qa,testing,java,bigdata,artificial intelligence,linux,python,devops',
#  'ios,objective c,javascript,swift,xcode,javascript,vue.js,reactjs,angular,python,django,flask,react native,flutter,javascript,ios,android,reactjs,react redux,typescript,javascript,webpack,devops,amazon web services,docker,kubernetes',
#  'php,mysql,symfony,laravel,javascript,vue.js,reactjs,angular,python,django,flask,react native,flutter,javascript,ios,android,reactjs,react redux,typescript,javascript,webpack,devops,amazon web services,docker,kubernetes',
#  'go,security',
#  'unity3d,game engine,cocos2d iphone,libgdx,unity5,javascript,ruby,sequel,postgresql,angularjs',
#  'c#,android,ios,git,xamarin,reactjs,javascript,postgresql,nosql,project management,product management,qa',
#  'c#,.net,azure,docker,geospatial',
#  'saml,oauth,openid connect,node.js,security,postgresql,amazon web services,postgresql,mongodb,golang,python,java,reactjs,node.js,web services,salesforce,zendesk,php,continuous integration,wordpress,node.js,laravel',
#  'pytorch,python,machine learning,fast ai,pipeline,reactjs,javascript,redux,git',
#  'go,python,c,java ee,hybris,spring,java',
#  'python,javascript,react.js',
#  'java,backend,microservices,kubernetes,machine learning',
#  'react native,flutter,javascript,ios,android,javascript,vue.js,reactjs,angular,python,django,flask,reactjs,react redux,typescript,javascript,webpack,devops,amazon web services,docker,kubernetes,node.js,javascript,express',
#  'java,javascript,kubernetes,elasticsearch,nosql,java,javascript,kubernetes,elasticsearch,nosql,amazon web services,linux,kubernetes,docker,jenkins,sysadmin',
#  'android,mobile,ios,dart,flutter,android,mobile,ios,flutter,dart',
#  'angular,python,docker,api,debugging,sql,xml,json',
#  'react native,node.js,mysql,webrtc,kurento,reactjs,node.js,javascript,react native,websocket',
#  'google analytics,instagram,facebook,seo,wordpress,python,sql,amazon web services,design,user experience,html,css,balsamiq',
#  'c#,.net,back,javascript',
#  'automation,java,rest assured,json,testng,java,spring boot,amazon web services,stream,microservices',
#  'java,spring boot,amazon web services,stream,microservices,automation,java,rest assured,json,testng',
#  'security,node.js,amazon web services,javascript,typescript,node.js,api,typescript,microservices,integration,python,typescript,amazon web services,javascript,kubernetes,amazon web services,linux,rbac,apache kafka,continuous integration,hl7 fhir,api,continuous integration,sql,api,hl7 fhir,json',
#  'java,c++,android,kotlin,java native interface,javascript,html,css',
#  'spring,spring security,spring boot,java,computer science,algorithm,time complexity,data structures,scala,akka',
#  'go,machine learning,python,node.js,javascript,vue.js,reactjs,angular,python,django,flask,react native,flutter,javascript,ios,android,reactjs,react redux,typescript,javascript,webpack,devops,amazon web services,docker,kubernetes',
#  'python,pyramid,postgresql,elasticsearch,security,amazon web services,terraform,postgresql,devops,sysadmin,reactjs,javascript,css,html,python',
#  'reactjs,javascript,css,html,python,python,pyramid,postgresql,elasticsearch,security,amazon web services,terraform,postgresql,devops,sysadmin',
#  'security,amazon web services,terraform,postgresql,devops,sysadmin,python,pyramid,postgresql,elasticsearch,reactjs,javascript,css,html,python',
#  'reactjs,frontend,web frontend,web,javascript',
#  'sitecore,asp.net,c#,javascript,asp.net core',
#  'python,reactjs,django,flask,sql',
#  'writing,video',
#  'ruby on rails,ruby,amazon web services,postgresql',
#  'python,flask,docker,gcp,matillion,ansible,docker,python 2to3,flask,gunicorn,sysadmin',
#  'node.js,security,postgresql,amazon web services,postgresql,mongodb,golang,python,java,reactjs,node.js,web services,salesforce,zendesk,saml,oauth,openid connect,php,continuous integration,wordpress,node.js,laravel',
#  'agile,product management,saas,web applications,erp,java,api,rest,microservices,web applications,reactjs,angularjs,vue.js,frontend,web applications',
#  'kentico,cms,.net,c#,mvc',
#  'java,hybris,progressive web apps,spring,javascript,angularjs,angular,css,java,intershop,progressive web apps,angularjs',
#  'rest,web services',
#  'javascript,angularjs,node.js,mongodb',
#  '',
#  'excel,ms access,ms office,ms word,outlook,reactjs,javascript,node.js,css,api,docker,gitlab,elasticsearch,logstash,php,symfony,mysql,typo3,extbase,python,php,android,symfony',
#  'amazon web services,python,data science,machine learning,kotlin,qa,testing,android,web,ios',
#  'qa,testing,android,web,ios,amazon web services,python,data science,machine learning,kotlin',
#  'node.js,api,mongodb,architecture,caching',
#  'amazon web services,docker,pulumi,kubernetes,terraform',
#  'php,mysql,javascript,angularjs,ansible',
#  'python,ruby,docker,amazon web services,configuration management,amazon web services,ruby,tdd,cloud,kubernetes,api design,google cloud platform,hashicorp vault,amazon web services,python,ruby',
#  'api,json,telephony,webrtc,sip',
#  'ruby on rails,postgresql,reactjs',
#  'c++,unix,.net,linux,json,c#,asp.net,javascript,mysql,object oriented analysis',
#  'c#,asp.net,javascript,mysql,object oriented analysis,c++,unix,.net,linux,json',
#  'elixir,graphql,postgresql,phoenix,erlang',
#  'java,bigdata,artificial intelligence,qa,testing,linux,python,devops',
#  'android,java,oop,kotlin,mysql,data warehouse,etl,bigdata,infrastructure']

# %% [markdown]
# ## Add technologies to DataFrame

# %%
df["Technologies"] = [",".join(techs) for techs in tech_tags]

# %% [markdown]
# ## Find level of experience

# %%
level = pd.read_json('golden-source-data.json')
pattern = r'\b|\b'.join(level['remote_jobs']['level'])

pattern

entry_levels = [(set(re.findall(pattern, str(job).lower()))) for job in job_det]


entry_levels_clean = []

for level in entry_levels:
    if level.intersection({'senior','experienced','sr','sr.','manager'}):
        entry_levels_clean.append('senior')
    elif level.intersection({'junior','jr','jr.'}):
        entry_levels_clean.append('junior')
    else:
        entry_levels_clean.append('other')
    
entry_levels_clean
# Out:
# ['senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'other',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'other',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'junior',
#  'junior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'junior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'other',
#  'other',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'junior',
#  'other',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'junior',
#  'other',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'junior',
#  'senior',
#  'junior',
#  'senior',
#  'senior',
#  'other',
#  'senior',
#  'senior',
#  'senior']

# %% [markdown]
# ## Add experience level to df

# %%
df['Experience Level'] = [level for level in entry_levels_clean]
df
# Out:
#                                                  Title  \
# 0                                      DevOps Engineer
# 1                       ActionScript / FLASH Developer
# 2    Mid to Senior Front End Developer - $75K to $1...
# 3                    Senior Python Engineer in Fintech
# 4    Computer Science Eng. to Brainstorm Topics for...
# ..                                                 ...
# 170                     Senior Linux Software Engineer
# 171                                  Software Engineer
# 172  Elixir/API Engineer with Growing Messaging Com...
# 173             Senior Software Engineer - Big Data/AI
# 174                                  Android Developer
#
#                                                   Link Experience Level  \
# 0    https://stackoverflow.com/jobs/378945/devops-e...           senior
# 1    https://stackoverflow.com/jobs/379299/actionsc...           senior
# 2    https://stackoverflow.com/jobs/358552/mid-to-s...           senior
# 3    https://stackoverflow.com/jobs/334701/senior-p...           senior
# 4    https://stackoverflow.com/jobs/350799/computer...           senior
# ..                                                 ...              ...
# 170  https://stackoverflow.com/jobs/367261/senior-l...           senior
# 171  https://stackoverflow.com/jobs/367258/software...            other
# 172  https://stackoverflow.com/jobs/335070/elixir-a...           senior
# 173  https://stackoverflow.com/jobs/342960/senior-s...           senior
# 174  https://stackoverflow.com/jobs/173378/android-...           senior
#
#                                           Technologies
# 0    java,ansible,docker,mongodb,amazon web service...
# 1              oracle,react,angular,graphql,javascript
# 2                                      shopify,laravel
# 3    machine learning,flask,pandas,apache,docker,sq...
# 4                                           scala,java
# ..                                                 ...
# 170                                 sql,c++,javascript
# 171                                 sql,c++,javascript
# 172                          graphql,elixir,postgresql
# 173                                        python,java
# 174                                    sql,kotlin,java
#
# [175 rows x 4 columns]

# %% [markdown]
# ## Save DataFrame

# %%
df.to_csv('dataframes/stackoverflow.csv', index = False)

# %% [markdown]
# ## Create a dictionary to count the times a technology is required

# %%
technologies_set = df['Technologies']

technologies_dict= {}

for technologies in technologies_set:
    for technology in technologies.split(','):
        if technology in technologies_dict.keys():
            technologies_dict[technology] += 1
        else:
            technologies_dict[technology] =  1

technologies_dict

{key: value for key, value in sorted(technologies_dict.items(), key=lambda item: item[1])}
# Out:
# {'tensorflow': 1,
#  'jquery': 1,
#  'heroku': 1,
#  'chromium': 1,
#  'rust': 1,
#  'clojure': 1,
#  'bash': 1,
#  'react bootstrap': 1,
#  'umbraco': 1,
#  'orchardcms': 1,
#  'canvas': 1,
#  'drupal': 1,
#  'dart': 1,
#  'elixir': 1,
#  'pandas': 2,
#  'firebase': 2,
#  'hadoop': 2,
#  'objective c': 2,
#  'shell': 2,
#  'oracle': 3,
#  'sass': 3,
#  'ansible': 4,
#  'shopify': 4,
#  'scala': 4,
#  'graphql': 5,
#  'golang': 5,
#  'pytorch': 5,
#  'c++': 5,
#  'xamarin': 5,
#  'kotlin': 7,
#  'nosql': 7,
#  'swift': 7,
#  'wordpress': 7,
#  'flutter': 7,
#  'laravel': 8,
#  'google cloud platform': 8,
#  'django': 9,
#  'apache': 11,
#  'elasticsearch': 11,
#  'flask': 13,
#  'mongodb': 14,
#  'vue': 14,
#  'machine learning': 15,
#  'typescript': 16,
#  '': 17,
#  'react native': 17,
#  'postgresql': 18,
#  'ruby': 23,
#  'angular': 33,
#  'node': 36,
#  'kubernetes': 41,
#  'java': 44,
#  'sql': 44,
#  'docker': 45,
#  'python': 58,
#  'react': 64,
#  'javascript': 70,
#  'amazon web services': 71}
