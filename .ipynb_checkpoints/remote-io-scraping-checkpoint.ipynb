# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# # Remote.io request

# %% [markdown]
# ## Find pagination length - Does this make sense?
# I'm able to find the number of element in each page but not the number of pages

# %%
url = 'https://www.remote.io/remote-jobs'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'lxml')

job_offers_length = len(soup.find_all('h3', attrs ={'class':'job-listing-title'}))
job_offers_length
# Out:
# 20

# %% [markdown]
# Chose 85 for the pagination lenght because it is around the 85th page that the jobs have more 4 months

# %%
pagination_length = 30
# pagination_length = 85


urls = ['https://www.remote.io/remote-jobs?p=' + str(i) for i in range(1,pagination_length)]

responses =[requests.get(url) for url in urls]

# %%
soups = [BeautifulSoup(response.content,'lxml') for response in responses]

# %% [markdown]
# ## Find all the job titles

# %%
all_h3 = [soup.find_all('h3', attrs ={'class':'job-listing-title'}) for soup in soups]
titles = [sublist.text for h3 in all_h3 for sublist in h3]

# %% [markdown]
# ## Find all the links to job description & request

# %%
all_links = [soup.find_all('a', attrs ={'class':'list-apply-button'}) for soup in soups]
links = ['https://www.remote.io' + sublist['href'] for a in all_links for sublist in a]

# %%
responses =[requests.get(url) for url in links]

# %%
soups = [BeautifulSoup(response.content,'lxml') for response in responses]

# %% [markdown]
# ## Find technologies

# %%
single_pages = [soup.find('div', attrs= {'class':'single-page-section'}).text for soup in soups]

# %% [markdown]
# #### Problems with this pattern:
# - Git cathes more things than the ones I want
# - Ui/Node/ React? probably hass the same problem
# - "Build a golden source'

# %%
technologies = pd.read_json('golden-source-data.json')
word_boundary_techs = "\b|\b".join(technologies['remote_jobs']['word_boundary_techs'])
no_boundary_techs = "\b|\b".join(technologies['remote_jobs']['no_boundary_techs'])

pattern
# Out:
# 'aws\x08|\x08git\x08|\x08ux\x08|\x08ui\x08|\x08seo\x08|\x08C#\x08|\x08r\x08|\x08c\x08|\x08c#\x08|\x08asp\x08|\x08vba'

# %%
single_page_words = [list(set(re.findall(pattern, text.lower())))for text in single_pages]
single_page_words
# Out:
# [['bash', 'docker', 'ansible', ' c', ' r'],
#  [' r', ' c', 'aws', 'angular'],
#  ['java', 'elasticsearch', 'scala', ' c', 'wordpress', ' r'],
#  [' r', ' c', 'swift', 'objective-c'],
#  ['javascript', ' c', 'rust', 'react', ' r', 'heroku'],
#  [' r', ' c'],
#  [' r', ' c', ' asp'],
#  [' r', ' c', 'shell', 'powershell'],
#  [' r', ' c'],
#  [' ui', 'javascript', 'scala', ' c', ' r'],
#  [' r', ' c'],
#  [' ui', 'javascript', ' c', 'seo', ' r', 'python'],
#  [' r', ' c', 'aws', 'oracle'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['kubernetes', 'powershell', 'docker', ' c', ' r', 'python', ' git'],
#  [' r', ' c'],
#  [' ui',
#   'javascript',
#   ' c',
#   ' asp',
#   ' r',
#   'jquery',
#   ' sql',
#   'microsoft sql server'],
#  [' ui', 'javascript', 'c#', 'aws', 'docker', ' c', 'react', ' r', 'python'],
#  ['java', 'javascript', 'docker', ' c', 'react', ' r', ' git'],
#  [' r', ' c', 'oracle'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' ui', 'javascript', 'typescript', 'angular', ' c', ' asp', ' r'],
#  ['flutter', 'kotlin', ' c', 'swift', ' r'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' r', ' c', 'google-cloud-platform'],
#  [' r', ' c', ' asp'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', 'vue', 'ruby', ' c', ' asp', ' r', 'jquery', ' sql'],
#  [' r', ' c', 'rust', ' ux'],
#  [' r', ' c'],
#  ['dynamodb',
#   'aws',
#   'scala',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  ['javascript', ' c', 'rust', 'react', ' r'],
#  ['javascript', ' c', 'rust', 'react', ' r', ' git', ' sql', ' node'],
#  [' r', ' c', 'rust', 'react native'],
#  ['aws', ' c', ' r', 'python', ' sql'],
#  ['javascript', ' r', ' c', 'rust'],
#  ['dynamodb',
#   'aws',
#   'kubernetes',
#   'scala',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  ['postgresql', ' c', 'rust', ' r', ' sql', 'heroku'],
#  ['java', 'nosql', 'aws', 'scala', ' c', 'rust', ' r', ' git', ' sql'],
#  [' ui', 'objective-c', ' ux', ' c', 'rust', 'swift', ' r', ' git'],
#  ['javascript', 'aws', 'ruby', 'docker', ' c', 'rust', ' r', ' git'],
#  [' r', ' c', 'angular'],
#  [' r', 'python', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'oracle'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['postgresql', 'aws', 'ansible', 'elixir', ' c', ' r'],
#  ['angular', 'graphql', 'scala', 'aws', 'docker', ' c', ' r', ' node'],
#  [' r', ' c', 'scala'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  ['scala', ' c', ' r'],
#  [' r', ' c'],
#  [' r', ' c', 'scala'],
#  ['python', ' r', ' c', 'java'],
#  [' r', ' c'],
#  ['javascript',
#   'vue',
#   'angular',
#   'graphql',
#   'aws',
#   ' c',
#   'apollo',
#   ' r',
#   ' node'],
#  ['javascript',
#   'vue',
#   'typescript',
#   'angular',
#   'graphql',
#   ' c',
#   'apollo',
#   ' r',
#   ' node'],
#  ['dynamodb',
#   'aws',
#   'kubernetes',
#   'scala',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  ['dynamodb',
#   'aws',
#   'scala',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  ['javascript',
#   'vue',
#   'angular',
#   'kubernetes',
#   'docker',
#   ' c',
#   'seo',
#   'react',
#   ' asp',
#   ' r',
#   ' git',
#   ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  ['seo', ' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['python', ' r', ' c'],
#  ['postgresql',
#   'javascript',
#   'aws',
#   'kubernetes',
#   'docker',
#   'ansible',
#   'puppet',
#   ' c',
#   'hadoop',
#   ' r',
#   'python',
#   ' git'],
#  ['javascript', ' r', ' c', 'java'],
#  [' r', ' c', ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['postgresql',
#   'javascript',
#   'aws',
#   'kubernetes',
#   'docker',
#   'ansible',
#   'puppet',
#   ' c',
#   'hadoop',
#   ' asp',
#   ' r',
#   'python',
#   ' git'],
#  [' r', ' c'],
#  [' r', ' c', ' sql'],
#  ['javascript',
#   'aws',
#   'scala',
#   'ruby',
#   ' c',
#   'machine-learning',
#   ' r',
#   'python',
#   ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java', 'vue', 'angular', 'scala', ' c', 'react', ' r'],
#  ['java',
#   ' ui',
#   'javascript',
#   'typescript',
#   'scala',
#   'kotlin',
#   ' c',
#   ' r',
#   'python',
#   ' node'],
#  ['c#', 'docker', ' c', ' r', ' git', ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'rust', ' asp'],
#  ['javascript', 'scala', 'aws', ' c', ' r', 'python'],
#  ['java', 'javascript', 'aws', 'scala', ' c', ' r', 'python', 'golang'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  ['seo', ' r', ' c'],
#  ['scala', 'powershell', ' c', ' r', 'python', 'shell'],
#  ['java', 'aws', ' c', ' r', ' node'],
#  ['java',
#   'scala',
#   'aws',
#   'kubernetes',
#   'docker',
#   ' c',
#   'machine-learning',
#   ' r',
#   ' git',
#   'golang'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', ' asp'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java',
#   'javascript',
#   'elasticsearch',
#   'nosql',
#   'kubernetes',
#   ' c',
#   ' r',
#   'python'],
#  ['nosql',
#   'graphql',
#   'flutter',
#   'aws',
#   'dart',
#   'kotlin',
#   ' c',
#   'swift',
#   'firebase',
#   'react',
#   'mongodb',
#   'tensorflow',
#   ' r',
#   ' git'],
#  ['seo', ' r', ' c', 'wordpress'],
#  ['javascript', 'aws', ' c', 'react native', ' r', ' node'],
#  [' ui', 'graphql', 'xamarin', ' c', ' r', 'redis', ' git'],
#  ['javascript', ' r', ' c'],
#  ['java', 'javascript', 'nosql', 'oracle', 'angular', 'scala', ' c', ' r'],
#  ['java', 'graphql', 'aws', 'docker', ' c', ' r'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  ['javascript', ' c', 'react', ' asp', ' r', 'jquery', ' sql'],
#  ['java', ' ui', 'javascript', 'kotlin', ' c', 'rust', ' r', 'python'],
#  ['elasticsearch',
#   'typescript',
#   'aws',
#   'kubernetes',
#   'ruby',
#   ' c',
#   'rust',
#   'react',
#   ' r'],
#  ['typescript', 'graphql', 'aws', 'kubernetes', ' c', 'rust', ' r', 'python'],
#  ['postgresql', 'aws', 'scala', 'ansible', ' c', ' r', 'python', 'shell'],
#  ['postgresql',
#   'javascript',
#   'elasticsearch',
#   'vue',
#   'aws',
#   'docker',
#   'ansible',
#   ' c',
#   'react',
#   ' r',
#   'python'],
#  ['postgresql',
#   'elasticsearch',
#   'javascript',
#   'aws',
#   'docker',
#   ' c',
#   ' r',
#   'python'],
#  [' r', ' c', ' asp'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  [' r', ' c', ' asp', 'scala'],
#  [' r', ' c', 'aws'],
#  [' r', ' c', 'scala'],
#  ['flask', 'aws', 'docker', 'ansible', ' c', ' r', 'python'],
#  [' r', ' c'],
#  ['javascript', ' r', ' c', ' ux'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['postgresql', 'javascript', 'scala', 'aws', ' c', 'rust', ' r', ' node'],
#  [' r', ' c', ' ux', ' asp'],
#  [' r', ' c', ' ux', 'scala'],
#  ['javascript', ' c', 'rust', 'react', ' r', ' git', ' sql', ' node'],
#  [' r', ' c', 'rust', 'react native'],
#  ['postgresql', ' c', 'rust', ' r', ' sql', 'heroku'],
#  ['javascript', ' r', ' c', 'rust'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['dynamodb',
#   'aws',
#   'scala',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  ['aws', ' c', ' r', 'python', ' sql'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['javascript', ' c', 'rust', 'react', ' r'],
#  ['java', 'javascript', 'aws', ' c', 'rust', ' r', 'python', ' node'],
#  ['javascript',
#   'angular',
#   'aws',
#   ' c',
#   'mongodb',
#   'react',
#   ' r',
#   'python',
#   ' git',
#   ' node'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  ['javascript', ' r', ' c', 'aws'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'oracle'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'oracle'],
#  ['scala',
#   'kubernetes',
#   'aws',
#   'bash',
#   'docker',
#   'ansible',
#   'powershell',
#   ' c',
#   ' r',
#   'python'],
#  ['graphql', 'scala', 'aws', 'ruby', 'docker', 'elixir', ' c', ' r', 'golang'],
#  ['javascript', 'vue', ' c', 'mongodb', ' r', ' node'],
#  [' r', ' c', ' git'],
#  ['javascript', 'aws', ' c', ' asp', ' r'],
#  ['aws', 'kubernetes', 'scala', ' c', ' r'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', ' sql'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' r', ' c', ' asp'],
#  ['python', ' r', ' c'],
#  ['javascript', 'c#', 'angular', ' c', ' asp', ' r'],
#  ['aws', 'scala', ' c', 'wordpress', 'hadoop', ' r', 'python', ' sql'],
#  ['javascript', 'angular', 'c#', ' c', ' asp', ' r', ' sql', ' node'],
#  [' ui', 'javascript', 'c#', 'aws', 'docker', ' c', 'react', ' r', 'python'],
#  ['scala', 'objective-c', ' ux', ' c', 'swift', ' asp', ' r'],
#  ['aws', 'kubernetes', 'scala', ' c', ' r'],
#  ['aws', 'kubernetes', 'scala', 'bash', 'powershell', ' c', ' r', 'python'],
#  ['javascript', 'c#', 'aws', ' c', 'react', ' r', ' sql'],
#  ['elasticsearch',
#   'python',
#   'aws',
#   'scala',
#   'cassandra',
#   ' c',
#   ' r',
#   'redis',
#   'golang'],
#  ['javascript', 'scala', 'aws', 'laravel', ' c', 'rust', 'react', ' r'],
#  [' c', ' r', 'python', ' git', ' sql'],
#  [' r', ' c', ' asp'],
#  ['java', 'javascript', 'docker', ' c', ' r', 'python'],
#  [' r', ' c', ' sql'],
#  [' r', ' c'],
#  [' r', ' c', 'kubernetes'],
#  [' r', ' c'],
#  ['postgresql',
#   ' ui',
#   'java',
#   'vue',
#   'typescript',
#   'angular',
#   'aws',
#   'docker',
#   ' c',
#   'rust',
#   ' r',
#   ' git',
#   ' node'],
#  ['angular', 'scala', ' c', ' asp', ' r', ' node'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['postgresql',
#   'java',
#   'javascript',
#   'c#',
#   'ruby',
#   'powershell',
#   'laravel',
#   ' c',
#   'python',
#   'jquery',
#   'shell'],
#  [' ui', 'typescript', 'c#', ' c', ' asp', ' r', ' sql'],
#  ['javascript',
#   'nosql',
#   'typescript',
#   'scala',
#   'laravel',
#   ' c',
#   'hadoop',
#   ' asp',
#   ' r',
#   'python',
#   ' git',
#   ' sql',
#   ' node'],
#  ['java', 'javascript', 'c#', ' c', ' r', ' sql'],
#  ['postgresql', 'javascript', 'aws', ' c', ' r', ' git', ' sql', ' node'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['postgresql',
#   'java',
#   'javascript',
#   'c#',
#   'ruby',
#   'powershell',
#   'laravel',
#   ' c',
#   'python',
#   'jquery',
#   'shell'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', ' c', 'react', ' r', ' git'],
#  ['python', ' r', ' c'],
#  ['javascript', 'angular', 'c#', ' c', ' asp', ' r', ' sql', ' node'],
#  ['aws', 'kubernetes', 'scala', 'docker', ' c', ' r'],
#  ['oracle', ' c', ' asp', ' r', ' git'],
#  ['java', ' r', ' c'],
#  [' ui', 'javascript', 'vue', 'aws', ' c', ' r', ' git'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', ' sql'],
#  ['flask', 'scala', ' c', ' r', 'python'],
#  ['javascript', ' r', ' c', 'vue'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['oracle', 'c#', ' c', ' r', ' git'],
#  [' r', ' c'],
#  ['javascript', 'nosql', ' c', 'rust', ' r', ' node'],
#  ['typescript', 'aws', 'docker', ' c', 'mongodb', 'react', ' r', ' node'],
#  ['postgresql',
#   'java',
#   'javascript',
#   'elasticsearch',
#   'scala',
#   'django',
#   ' ux',
#   'ansible',
#   ' c',
#   ' r',
#   'python',
#   ' sql'],
#  ['java', 'postgresql', 'aws', 'scala', 'bash', 'docker', ' c', ' r', ' git'],
#  [' r', 'javascript', ' c', ' ui'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' ui',
#   'javascript',
#   'aws',
#   'docker',
#   ' c',
#   'mongodb',
#   'react',
#   ' r',
#   ' node'],
#  ['javascript', 'typescript', 'angular', ' c', ' asp', ' r', ' sql'],
#  ['java', 'oracle', ' c', ' r', ' sql'],
#  ['java', 'oracle', ' c', ' r', ' sql'],
#  ['javascript', ' c', 'rust', 'react', ' r', ' git', ' sql', ' node'],
#  [' r', ' c'],
#  ['oracle', 'aws', ' c', ' r', ' sql'],
#  ['java', 'angular', 'aws', ' c', ' r', ' node'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  ['javascript', 'django', ' c', ' r', 'python', ' git'],
#  ['javascript', ' r', ' c', 'rust'],
#  ['java', 'aws', 'docker', ' c', ' r'],
#  ['aws', ' c', ' r', 'python', ' sql'],
#  ['dynamodb',
#   'aws',
#   'scala',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  [' c', 'rust', ' r', ' git', ' node'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['postgresql',
#   'elasticsearch',
#   'ruby',
#   ' c',
#   'rust',
#   'react',
#   ' r',
#   ' sql',
#   'heroku'],
#  ['javascript', ' c', 'rust', 'react', ' r'],
#  [' r', ' c', 'rust', 'react native'],
#  ['apache', ' r', ' c', 'mongodb'],
#  ['postgresql', 'scala', 'aws', 'kotlin', ' c', ' r', 'python', ' git'],
#  ['java', 'typescript', 'aws', 'kubernetes', 'docker', ' c', ' r', 'python'],
#  ['javascript',
#   'vue',
#   'shell',
#   'angular',
#   'bash',
#   'docker',
#   'laravel',
#   ' c',
#   'wordpress',
#   ' r',
#   ' git',
#   ' node'],
#  ['java',
#   'javascript',
#   'flask',
#   'kubernetes',
#   'docker',
#   ' c',
#   ' asp',
#   ' r',
#   'python',
#   ' sql'],
#  ['java', 'javascript', 'flask', ' c', ' asp', ' r', 'python', ' sql'],
#  ['javascript', 'nosql', 'scala', ' c', ' r', 'python'],
#  ['javascript', ' c', ' r', 'jquery', ' sql'],
#  [' r', ' c'],
#  ['seo', ' r', ' c'],
#  ['elasticsearch',
#   'javascript',
#   'scala',
#   'aws',
#   ' c',
#   'mongodb',
#   'react',
#   ' r',
#   ' node'],
#  ['java', 'aws', 'kubernetes', ' c', 'google-cloud-platform', ' r', 'python'],
#  [' r', ' c'],
#  ['aws', 'bash', 'docker', ' c', ' r', 'golang'],
#  ['angular',
#   'aws',
#   'scala',
#   'kotlin',
#   'docker',
#   ' c',
#   'rust',
#   'react',
#   ' r',
#   ' sql',
#   ' node'],
#  ['aws', ' c', ' r', 'python', ' sql'],
#  ['java', ' r', ' c', 'rust'],
#  ['java', ' r', ' c'],
#  ['xamarin', ' c', ' r', ' ui'],
#  [' r', ' c'],
#  [' r', ' c', 'ansible'],
#  [' r', ' c'],
#  [' r', ' c', 'dart', 'aws'],
#  [' r', ' c'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  ['javascript', 'typescript', ' c', ' r', 'python'],
#  ['java', ' r', ' c', 'python'],
#  ['javascript', ' r', ' c'],
#  ['elasticsearch', 'vue', 'laravel', ' c', 'rust', ' r', 'python'],
#  [' r', ' c'],
#  ['java', 'angular', 'aws', 'scala', ' c', ' r', ' node'],
#  ['javascript',
#   'typescript',
#   'angular',
#   'scala',
#   'ruby',
#   'django',
#   ' c',
#   'react',
#   ' r',
#   'python',
#   ' node'],
#  [' r', ' c'],
#  ['postgresql', 'django', ' c', ' r', 'python', ' git'],
#  ['aws', ' c', ' r', 'python', ' sql'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java',
#   'dynamodb',
#   'aws',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'apache',
#   ' r',
#   'mariadb'],
#  ['javascript',
#   'angular',
#   'django',
#   'laravel',
#   ' c',
#   ' r',
#   'python',
#   ' git',
#   ' sql',
#   ' node'],
#  [' r', ' c'],
#  ['javascript', 'scala', ' c', 'wordpress', ' r', ' git'],
#  ['python', ' r', ' c'],
#  [' r', ' c', 'rust', 'react native'],
#  ['javascript', 'vue', 'aws', 'laravel', ' c', ' r', ' git'],
#  ['postgresql',
#   'javascript',
#   'angular',
#   'drupal',
#   'docker',
#   ' c',
#   ' r',
#   ' git',
#   ' sql',
#   ' node'],
#  ['scala', 'aws', 'docker', ' c', ' r', ' node'],
#  [' r', ' c', 'mariadb', 'kubernetes'],
#  ['kubernetes', 'docker', ' c', ' r', ' git'],
#  ['java',
#   'vue',
#   'aws',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   ' r',
#   ' git',
#   ' node',
#   'heroku'],
#  [],
#  [' r', ' c'],
#  ['java', 'aws', ' c', ' r', ' sql'],
#  [' r', ' c'],
#  [' r', ' c', 'assembly', ' asp'],
#  [' r', ' c', ' git'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', 'aws', ' c', ' r', 'golang'],
#  [' ui', 'javascript', 'drupal', 'scala', ' ux', ' c', 'rust', ' r', ' git'],
#  ['javascript',
#   'jquery',
#   'aws',
#   'docker',
#   'laravel',
#   ' c',
#   ' r',
#   ' git',
#   ' node'],
#  ['scala', 'aws', 'kubernetes', 'docker', ' c', ' r', 'apache', 'shell'],
#  ['angular', ' c', ' asp', ' r', ' sql'],
#  ['javascript', 'vue', 'aws', 'scala', 'laravel', ' c', ' r', ' git'],
#  [' r', ' c', 'aws', 'google-cloud-platform'],
#  ['scala', ' c', 'rust', 'google-cloud-platform', ' r', 'python'],
#  ['aws', 'kubernetes', 'django', ' c', ' r', 'python'],
#  [' r', ' c', 'rust'],
#  ['postgresql',
#   'javascript',
#   'aws',
#   'kubernetes',
#   'docker',
#   'ansible',
#   'puppet',
#   ' c',
#   'hadoop',
#   'google-cloud-platform',
#   ' r',
#   'python',
#   ' git'],
#  ['java',
#   'postgresql',
#   'javascript',
#   'aws',
#   'kubernetes',
#   'docker',
#   'ansible',
#   'puppet',
#   ' c',
#   'hadoop',
#   'google-cloud-platform',
#   ' r',
#   'python',
#   ' git'],
#  ['java',
#   'elasticsearch',
#   'nosql',
#   'aws',
#   'scala',
#   'kotlin',
#   ' c',
#   'mongodb',
#   ' r',
#   'apache',
#   ' sql'],
#  ['postgresql',
#   'elasticsearch',
#   'nosql',
#   'javascript',
#   'flask',
#   'angular',
#   'aws',
#   'django',
#   ' c',
#   'mongodb',
#   'apache',
#   ' r',
#   'python',
#   'jquery'],
#  [' r', ' c'],
#  ['flask', ' ux', ' c', ' r', 'python', ' sql'],
#  ['elasticsearch',
#   'vue',
#   'typescript',
#   'dynamodb',
#   'aws',
#   ' c',
#   'react',
#   ' r',
#   ' git',
#   ' node'],
#  [' ui', 'javascript', 'dynamodb', 'ruby', ' c', ' r', 'python', ' node'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java',
#   'javascript',
#   'typescript',
#   'aws',
#   'kubernetes',
#   'bash',
#   'docker',
#   'ansible',
#   ' c',
#   ' r',
#   'python'],
#  [' r', ' c'],
#  ['postgresql',
#   'elasticsearch',
#   'aws',
#   'ansible',
#   'puppet',
#   ' c',
#   ' r',
#   'python',
#   ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['postgresql', 'scala', ' ux', 'django', 'docker', ' c', ' r', 'python'],
#  ['postgresql',
#   'elasticsearch',
#   ' c',
#   'rust',
#   'react',
#   ' r',
#   ' sql',
#   'heroku'],
#  ['aws',
#   'kubernetes',
#   'bash',
#   'docker',
#   'ansible',
#   ' c',
#   ' r',
#   'python',
#   ' git'],
#  ['java',
#   'javascript',
#   'typescript',
#   'angular',
#   'graphql',
#   'scala',
#   'flask',
#   'aws',
#   ' c',
#   'react',
#   ' r',
#   'python'],
#  [' c'],
#  [' r', ' c', ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'kubernetes'],
#  [' r', ' c', 'machine-learning'],
#  ['scala', 'aws', ' c', ' asp', 'google-cloud-platform', ' r', 'python'],
#  ['java', 'javascript', ' c', 'rust', ' r'],
#  ['dynamodb',
#   'aws',
#   'scala',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  [' ui', 'javascript', 'kubernetes', 'docker', ' c', ' r', ' sql', ' node'],
#  ['javascript', ' c', 'rust', 'react', ' r'],
#  [' r', ' c', 'rust'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['javascript', 'aws', ' c', ' r', ' sql', ' node'],
#  [' c', 'rust', ' r', ' git', ' node'],
#  [' r', ' c', 'rust', 'react'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['aws', 'kotlin', ' c', 'swift', 'react', 'react native', ' r', ' node'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'scala'],
#  ['postgresql',
#   'javascript',
#   'scala',
#   'kubernetes',
#   'docker',
#   ' c',
#   ' asp',
#   ' r',
#   ' node'],
#  [' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' c', ' asp', ' r', ' sql', 'microsoft sql server'],
#  ['java', ' r', ' c'],
#  ['javascript', 'nosql', 'aws', ' c', 'react', 'react native', ' r', ' node'],
#  ['scala',
#   'aws',
#   'kubernetes',
#   'django',
#   ' c',
#   'swift',
#   'rust',
#   ' r',
#   'python'],
#  [' c', 'rust', ' asp', ' r', ' sql'],
#  [' r', ' c'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  ['javascript', ' r', ' c', 'wordpress'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', 'vue', 'angular', 'aws', ' c', ' r', 'apache', ' git', ' sql'],
#  [' r', ' c', 'angular'],
#  ['javascript', 'vue', 'aws', ' c', ' r', ' git', ' node'],
#  ['javascript',
#   'vue',
#   'aws',
#   'django',
#   ' c',
#   'apollo',
#   ' r',
#   'python',
#   ' git'],
#  ['javascript',
#   'typescript',
#   'graphql',
#   ' c',
#   'apollo',
#   'react',
#   ' r',
#   ' node'],
#  [' ui', 'javascript', ' c', 'react native', ' r', ' git', ' node'],
#  ['javascript', 'nosql', 'aws', ' c', 'swift', 'react native', ' r'],
#  ['java',
#   ' ui',
#   'javascript',
#   'objective-c',
#   ' c',
#   'swift',
#   'react native',
#   ' r'],
#  ['elasticsearch',
#   'aws',
#   'kubernetes',
#   'django',
#   'docker',
#   'ansible',
#   ' c',
#   'hadoop',
#   ' r',
#   'python'],
#  ['javascript',
#   'scala',
#   'aws',
#   'kubernetes',
#   'django',
#   ' c',
#   'react',
#   ' r',
#   'python'],
#  [' ui', 'vue', 'typescript', 'angular', ' ux', ' c', ' r'],
#  ['elixir', ' c', ' r', ' git', 'golang'],
#  ['graphql', 'aws', 'kubernetes', 'docker', ' c', ' r', ' git'],
#  ['aws',
#   'kubernetes',
#   'docker',
#   'elixir',
#   ' c',
#   ' r',
#   'apache',
#   ' git',
#   'golang'],
#  ['seo', ' r', ' c'],
#  ['java', 'scala', ' c', ' asp', ' r'],
#  [' r', ' c', 'scala'],
#  ['java',
#   'scala',
#   'docker',
#   ' c',
#   'unreal engine',
#   ' r',
#   'python',
#   ' git',
#   'shell'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', ' asp'],
#  [' r', ' c'],
#  [' r', ' c', 'wordpress', 'aws'],
#  [' r', ' c'],
#  [' r', ' c', 'rust'],
#  ['javascript', ' c', 'rust', 'react', ' r'],
#  ['java', 'angular', 'aws', ' c', ' r', 'mariadb'],
#  ['javascript', 'aws', 'scala', ' c', 'rust', ' r'],
#  ['drupal', 'aws', 'docker', 'puppet', ' c', ' r', 'python', ' git', 'golang'],
#  ['javascript', 'elasticsearch', ' c', ' r', ' sql'],
#  ['elasticsearch', 'kubernetes', 'docker', ' c', ' r', ' git'],
#  ['aws', ' c', 'google-cloud-platform', ' r', 'python'],
#  ['postgresql', 'javascript', ' c', ' r', ' git', ' sql', ' node'],
#  [' ui', ' c', 'swift', ' r'],
#  ['java',
#   ' ui',
#   'javascript',
#   'nosql',
#   'angular',
#   'dynamodb',
#   'aws',
#   ' c',
#   ' r',
#   'apache',
#   ' git',
#   ' node'],
#  ['flask', 'aws', 'docker', 'ansible', ' c', ' r', 'python', ' sql'],
#  ['java', ' ui', 'javascript', 'kotlin', ' c', ' r', 'python'],
#  [' r', ' c', 'scala'],
#  ['java',
#   'javascript',
#   'typescript',
#   'scala',
#   'kubernetes',
#   'docker',
#   ' c',
#   'rust',
#   ' r',
#   ' node'],
#  [' r', ' c', 'rust', ' sql'],
#  ['javascript',
#   'angular',
#   ' c',
#   'rust',
#   ' asp',
#   ' r',
#   'jquery',
#   ' sql',
#   'microsoft sql server'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', 'scala', 'ruby', ' c', 'rust', ' r', ' node'],
#  [' ui', 'typescript', 'angular', ' c', ' r'],
#  [' r', ' c', 'vue'],
#  [' ui',
#   'javascript',
#   'angular',
#   ' c',
#   'rust',
#   ' asp',
#   ' r',
#   'jquery',
#   'microsoft sql server'],
#  ['java',
#   'nosql',
#   'scala',
#   'aws',
#   'docker',
#   'puppet',
#   ' c',
#   ' r',
#   'python',
#   ' sql'],
#  ['java', 'bash', 'ansible', ' c', 'swift', ' r', 'python', 'shell'],
#  ['javascript',
#   'angular',
#   ' c',
#   'rust',
#   ' asp',
#   ' r',
#   'jquery',
#   ' sql',
#   'microsoft sql server'],
#  [' r', ' c', 'scala'],
#  ['javascript', ' c', 'react', ' asp', ' r', 'jquery', ' sql'],
#  ['java',
#   'aws',
#   'bash',
#   'docker',
#   'kotlin',
#   ' c',
#   'tensorflow',
#   'pandas',
#   'machine-learning',
#   ' r',
#   'python',
#   ' git'],
#  ['java',
#   'aws',
#   'ansible',
#   'puppet',
#   ' c',
#   'google-cloud-platform',
#   ' r',
#   'python',
#   ' git'],
#  ['scala', ' c', 'machine-learning', 'apache', ' r', 'python', ' git', ' sql'],
#  ['javascript', 'scala', 'laravel', ' c', ' r', ' git'],
#  ['elasticsearch',
#   'scala',
#   'kubernetes',
#   'aws',
#   'docker',
#   ' c',
#   'rust',
#   'apache',
#   ' r',
#   'python'],
#  ['python', ' r', ' c'],
#  [' r', ' c'],
#  ['javascript', ' c', ' r', ' git', ' sql', 'heroku'],
#  [' ui', ' c', ' asp', ' r', 'python', ' git'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  ['graphql', ' c', 'swift', ' r', ' git'],
#  ['javascript', 'jquery', 'seo', ' c', 'wordpress', ' r', ' git'],
#  ['typescript', 'angular', ' ux', ' c', 'firebase', ' r', ' node'],
#  [' r', 'kubernetes', ' c', ' ux'],
#  ['flask',
#   'scala',
#   'aws',
#   'bash',
#   'docker',
#   ' c',
#   'pandas',
#   'google-cloud-platform',
#   'apache',
#   ' r',
#   'python',
#   ' git',
#   ' sql'],
#  ['java', ' ui', 'objective-c', ' ux', ' c', 'swift', ' r'],
#  ['javascript', 'vue', 'django', ' c', ' r', 'python', ' sql'],
#  [' r', ' c'],
#  [' r', ' c', 'rust'],
#  ['javascript', ' r', ' c', 'python'],
#  ['java', 'javascript', ' c', ' r', 'python', ' git'],
#  ['java', 'javascript', ' c', ' r', 'python', ' git'],
#  ['javascript',
#   'aws',
#   'bash',
#   'ansible',
#   ' c',
#   ' r',
#   'python',
#   ' git',
#   'shell'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'oracle'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'aws'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java', 'javascript', ' c', 'rust', ' r'],
#  ['dynamodb',
#   'aws',
#   'scala',
#   'kubernetes',
#   'docker',
#   'ansible',
#   ' c',
#   'rust',
#   ' r',
#   ' git'],
#  [' r', ' c', 'rust', 'react native'],
#  [' r', ' c', 'rust', 'react'],
#  [' c', 'rust', ' r', ' git', ' node'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['javascript', 'aws', ' c', ' r', ' sql', ' node'],
#  ['postgresql', 'elasticsearch', 'ruby', ' c', ' r', ' sql', 'heroku'],
#  [' r', ' c', 'rust'],
#  ['nosql',
#   'angular',
#   'aws',
#   'docker',
#   ' c',
#   'mongodb',
#   ' r',
#   'python',
#   ' git'],
#  ['nosql', 'aws', 'docker', ' c', 'mongodb', ' r', 'python'],
#  ['javascript',
#   'elasticsearch',
#   'aws',
#   'docker',
#   ' c',
#   'mongodb',
#   'react',
#   ' r',
#   ' node'],
#  [' r', ' c', 'aws'],
#  [' ui', 'javascript', 'scala', ' c', ' r', ' node'],
#  ['docker', ' c', 'pandas', 'machine-learning', ' r', 'python', ' sql'],
#  [' r', ' c', ' git', 'xamarin'],
#  [' ui', 'javascript', 'scala', ' c', ' asp', ' r', 'python'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', 'javascript', ' c', ' node'],
#  ['c#', 'docker', 'rabbitmq', ' c', ' asp', ' r'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', 'graphql', 'aws', ' c', 'apollo', 'react', ' r', ' node'],
#  ['python', ' r', ' c'],
#  ['java', 'aws', ' c', ' r', 'apache', 'shell'],
#  [' r', ' c'],
#  ['angular', 'c#', ' c', ' r', ' sql'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['scala', ' c', ' r'],
#  ['aws', 'bash', 'puppet', ' c', 'wordpress', ' r', 'apache', ' git'],
#  ['java', ' ui', 'javascript', 'vue', ' ux', ' c', ' r', 'jquery'],
#  [' c'],
#  ['javascript', 'puppet', ' c', ' r', ' git'],
#  [' r', ' c', ' sql'],
#  [' r', ' c'],
#  [' r', ' c', 'rust'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['javascript', 'typescript', ' c', 'react', ' r'],
#  [' r', ' c', 'scala'],
#  [' r', ' c', ' sql', 'oracle'],
#  ['c#', 'aws', 'f#', ' c', ' r', 'python'],
#  ['flask', 'django', ' c', 'rust', ' r', 'python', ' git'],
#  ['kubernetes', ' c', 'google-cloud-platform', ' r', 'python'],
#  [' r', ' c', 'apollo'],
#  [' c', 'apollo', ' r'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c', 'scala'],
#  [' r', ' c'],
#  [' r', ' c'],
#  [' r', ' c'],
#  ['java', 'nosql', 'scala', 'aws', ' c', 'rust', ' r', ' git', ' sql'],
#  ['python', ' r', ' c', 'shell'],
#  ['angular', 'aws', 'docker', ' c', ' r', 'python'],
#  ['javascript', 'ruby', ' c', 'wordpress', ' asp', ' r', 'jquery'],
#  ['postgresql',
#   'javascript',
#   'vue',
#   'ruby',
#   ' c',
#   'react',
#   ' r',
#   'redis',
#   'jquery'],
#  ['postgresql',
#   'elasticsearch',
#   'dynamodb',
#   'aws',
#   ' c',
#   ' r',
#   ' git',
#   ' sql',
#   'microsoft sql server'],
#  [' r', ' c', 'rust', 'react native'],
#  ['postgresql',
#   'java',
#   'aws',
#   ' c',
#   'rust',
#   'mongodb',
#   ' asp',
#   ' r',
#   'python',
#   'golang',
#   ' node'],
#  ['scala', 'aws', ' c', 'rust', ' r', ' node'],
#  ['nosql', 'aws', 'kubernetes', 'scala', ' c', 'rust', ' r', ' sql'],
#  ['laravel', ' c', 'wordpress', 'rust', ' r', ' git', ' node'],
#  ['postgresql', ' c', 'rust', 'mongodb', ' r', ' node'],
#  ['javascript',
#   'vue',
#   'angular',
#   'scala',
#   'aws',
#   'laravel',
#   ' c',
#   ' r',
#   ' git'],
#  [' r', ' c']]

# %% [markdown]
# ## Data frame 🙃

# %%
df = pd.DataFrame(titles, columns=['Title'])


df['Link'] = links
df['Technologies'] = [",".join(techs) for techs in single_page_words]
df

# %% [markdown]
# ## React not invited to the party!
# Here I found out that it's not repeating react when we have react native 🎊

# %%
react_native_rows = df[df['Technologies'].str.contains('react native')]
react_native_rows

# %% [markdown]
# ## Create a dictionary to count the times a technology is required

# %%
technologies_set = df['Technologies']

technologies_dict= {}

for technologies in technologies_set:
    for technology in technologies.split(','):
        if technology in technologies_dict.keys():
            technologies_dict[technology] += 1
        else:
            technologies_dict[technology] =  1

technologies_dict

{key: value for key, value in sorted(technologies_dict.items(), key=lambda item: item[1])}
