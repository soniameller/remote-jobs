# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import math

# %% [markdown]
# ## Find the number of pages

# %%
url = 'https://stackoverflow.com/jobs/remote-developer-jobs'

response = requests.get(url)
soup = BeautifulSoup(response.content, features = 'lxml')

jobs_nb = soup.find('div', attrs = {'class':'js-search-title'}).findChild().text
jobs_nb = re.findall('\d+', jobs_nb)[0]

#QUES - Why does the website shop 116 jobs and here I receive 416  🤔

pages = math.ceil((int(jobs_nb)/25))

# %% [markdown]
# ## Set url to scrape list of jobs

# %%
#Erase this line when I find out why I have 17 pages
pages = 7
urls = ['https://stackoverflow.com/jobs/remote-developer-jobs?pg='+ str(page) for page in range(1,pages+1)]

# %%
responses =[requests.get(url) for url in urls]

# %%
soups = [BeautifulSoup(response.content,'lxml') for response in responses]

# %%
a_tags = [soup.find_all('a', {'class':'s-link stretched-link'}) for soup in soups]
titles = [a.text for sublist in a_tags for a in sublist]

# %%
tech_tags = [soup.find_all('a', attrs ={'class': 'post-tag'})]
technologies = [a.text for tag in tech_tags for a in tag]
list(set(technologies))
# Out:
# ['orchardcms',
#  'postgresql',
#  'machine-learning',
#  'umbraco',
#  'finance',
#  'jenkins',
#  'sysadmin',
#  'azure',
#  'sdk',
#  'spring',
#  'ruby',
#  'nosql',
#  'excel',
#  'docker',
#  'ios',
#  'flask',
#  'devops',
#  'web-services',
#  'chef',
#  'reactjs',
#  'kubernetes',
#  'apex',
#  '.net-core',
#  'amazon-web-services',
#  'vue.js',
#  'seo',
#  'ansible',
#  'graphql',
#  'html5-canvas',
#  'quantitative-finance',
#  'angular',
#  'episerver',
#  'dotnetnuke',
#  'javascript',
#  'math',
#  'node.js',
#  'dsc',
#  'microservices',
#  'spring-boot',
#  'salesforce-lightning',
#  'angularjs',
#  'cypress',
#  'aura-framework',
#  'android',
#  'asp.net',
#  'sitecore',
#  'python',
#  'swift',
#  'java',
#  'babel',
#  'symfony',
#  '.net',
#  'typescript',
#  'c#',
#  'elasticsearch',
#  'spinnaker',
#  'react-bootstrap',
#  'php',
#  'salesforce',
#  'django',
#  'go',
#  'agile',
#  'algorithm',
#  'linux',
#  'salesforce-communities',
#  'kotlin',
#  'terraform',
#  'google-cloud-platform']

# %%
links = ['https://stackoverflow.com' + a['href'] for sublist in a_tags for a in sublist]

# %% [markdown]
# ## DataFrame 🙃

# %%
df = pd.DataFrame(titles,columns = ["Titles"])
df['Links'] = links
df
# Out:
#                                                 Titles  \
# 0                       Software Engineer - DevOps/SRE
# 1    DevOps Engineer (Go, Terraform, Ansible, AWS) ...
# 2                   Systems Administrator (Linux, PHP)
# 3                 Managed Service System Engineer - US
# 4             PHP-/Symfony-Entwickler (m/w/d) gesucht!
# ..                                                 ...
# 170        Data Engineer (Contract, £350-£550/day DoE)
# 171                     Senior Web Developer (Angular)
# 172             Lead Technical Support & Test Engineer
# 173        Experienced Backend Engineer - C#/.Net Core
# 174                        Principal Software Engineer
#
#                                                  Links
# 0    https://stackoverflow.com/jobs/369052/software...
# 1    https://stackoverflow.com/jobs/377997/devops-e...
# 2    https://stackoverflow.com/jobs/357276/systems-...
# 3    https://stackoverflow.com/jobs/301008/managed-...
# 4    https://stackoverflow.com/jobs/275301/php-symf...
# ..                                                 ...
# 170  https://stackoverflow.com/jobs/299629/data-eng...
# 171  https://stackoverflow.com/jobs/202880/senior-w...
# 172  https://stackoverflow.com/jobs/374521/lead-tec...
# 173  https://stackoverflow.com/jobs/352087/experien...
# 174  https://stackoverflow.com/jobs/374393/principa...
#
# [175 rows x 2 columns]

# %% [markdown]
# ## Set url for scraping the job descriptions

# %%
description_responses =[requests.get(url) for url in links]

# %%
description_soups = [BeautifulSoup(response.content,'lxml') for response in description_responses]

# %%
tags = [soup.find_all('a', attrs = {'class':'post-tag'}) for soup in description_soups]

# %%
description_technologies = []
for a in tags:
    description_technologies.append(','.join([i.text for i in a]))
description_technologies
# Out:
# ['google-cloud-platform,kubernetes,python,azure',
#  'terraform,ansible,amazon-web-services,go,postgresql,python,go,kubernetes,docker,amazon-web-services,javascript,reactjs,node.js,php,c#,reactjs,javascript,html,css,node.js,reactjs,ruby-on-rails,ruby,typescript,postgresql,reactjs,javascript,typescript',
#  'devops,php,linux',
#  'linux,web-services,linux,tomcat,apache,python',
#  'php,android,symfony,reactjs,javascript,node.js,css,api,javascript,reactjs,node.js,nosql,git,docker,gitlab,elasticsearch,logstash,php,symfony,mysql,typo3,extbase,excel,ms-access,ms-office,ms-word,outlook',
#  'amazon-web-services,angular,react-bootstrap,node.js,docker,amazon-web-services,angularjs,javascript,postgresql,reactjs',
#  'apex,salesforce-lightning,salesforce,aura-framework,salesforce-communities',
#  'episerver,umbraco,sitecore,dotnetnuke,orchardcms,asp.net,c#,tsql,javascript,sql,user-interface,user-experience,web-accessibility',
#  '.net,chef,ruby,c#,dsc',
#  'ios,swift,sdk,java,reactjs,javascript,node.js,npm,tdd,nightwatch.js,jenkins,automation,selenium,javascript,amazon-web-services,devops,amazon-rds,sql',
#  'reactjs,javascript,typescript,babel,cypress,python,postgres,mongodb,flask,django,python,postgresql,flask,cherrypy,mongodb,python,flask,mongodb,javascript,reactjs,angular,angularjs,vue.js,kubernetes,amazon-web-services,python,docker,splunk',
#  'amazon-web-services,linux,kubernetes,docker,jenkins,sysadmin,java,javascript,kubernetes,elasticsearch,nosql,java,javascript,kubernetes,elasticsearch,nosql',
#  'java,javascript,kubernetes,elasticsearch,nosql,java,javascript,kubernetes,elasticsearch,nosql,amazon-web-services,linux,kubernetes,docker,jenkins,sysadmin',
#  'algorithm,python,machine-learning,kotlin,java,spring,spinnaker',
#  'kotlin,java,spring,spinnaker,algorithm,python,machine-learning',
#  'c#,excel,math,quantitative-finance,finance',
#  'reactjs,angularjs,node.js,typescript,vue.js',
#  'microservices,kubernetes,spring-boot,java,javascript',
#  'reactjs,node.js,html5-canvas,seo,amazon-web-services',
#  'python,django,flask,javascript,vue.js,reactjs,angular,react-native,flutter,javascript,ios,android,reactjs,react-redux,typescript,javascript,webpack,devops,amazon-web-services,docker,kubernetes,node.js,javascript,express',
#  'reactjs,agile,javascript',
#  'javascript,reactjs,amazon-web-services',
#  'typescript,reactjs,graphql',
#  'c#,asp.net,.net-core,javascript',
#  'amazon-web-services,jenkins,docker,devops,linux,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql',
#  'mysql,php,amazon-web-services,docker,varnish,drupal,scoping',
#  'amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,javascript,node.js,express,sql,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql,mobile,android,ios,ionic2,ionic-framework',
#  'python,scikit-learn,pytorch,docker,kubernetes',
#  'shell,linux,amazon-web-services,unix,sysadmin,qa,testing,manual-testing',
#  'qa,testing,manual-testing,shell,linux,amazon-web-services,unix,sysadmin',
#  'web-services,salesforce,apex,java,sql,java-ee,angularjs,hibernate,sfdc,apex,visualforce,b2b,xml,soap,salesforce,apex,visualforce,spring,java,oracle,guidewire,java,java-ee,sql',
#  'c++,linux,c,windows,cloud,c++,linux,windows,security,linux,windows,security',
#  'amazon-web-services,devops,amazon-rds,sql,reactjs,javascript,node.js,npm,tdd,nightwatch.js,jenkins,automation,selenium,javascript,ios,swift,sdk,java',
#  'apache,machine-learning,algorithm,r,python,machine-learning,data-science,statistics,java,spring,jakarta-ee,rest,sql,amazon-web-services,automation,sql,machine-learning,python,statistics,business-intelligence',
#  'sql,machine-learning,python,statistics,business-intelligence,r,python,machine-learning,data-science,statistics,java,spring,jakarta-ee,rest,sql,apache,machine-learning,algorithm,amazon-web-services,automation',
#  'r,python,machine-learning,data-science,statistics,java,spring,jakarta-ee,rest,sql,apache,machine-learning,algorithm,amazon-web-services,automation,sql,machine-learning,python,statistics,business-intelligence',
#  'amazon-web-services,automation,r,python,machine-learning,data-science,statistics,java,spring,jakarta-ee,rest,sql,apache,machine-learning,algorithm,sql,machine-learning,python,statistics,business-intelligence',
#  'go,angular,amazon-web-services,docker,python,go,amazon-web-services,docker,mongodb,go,angular,amazon-web-services,devops,mongodb',
#  'apache-flink,java,java,apache-flink,flink-streaming,kubernetes',
#  'reactjs,react-redux,typescript,javascript,webpack,javascript,vue.js,reactjs,angular,python,django,flask,react-native,flutter,javascript,ios,android,devops,amazon-web-services,docker,kubernetes,node.js,javascript,express',
#  'c,python,c++,php,javascript,laravel,node.js,reactjs,node.js,mongodb,amazon-web-services,reactjs,docker,javascript,html,css,vuejs,angular,sysadmin,php,javascript,wordpress,html,css,sysadmin,python,javascript,c,android,kivy',
#  'reactjs,angular,node.js,django,laravel',
#  'amazon-web-services,python,ruby,amazon-web-services,ruby,tdd,python,ruby,docker,amazon-web-services,configuration-management,cloud,kubernetes,api-design,google-cloud-platform,hashicorp-vault',
#  'sql,tableau,data-visualization,visualization,rest,identity-management,identitymanager,soap,atlassian-crowd,.net,c#,angular,agile,reactjs,.net,asp.net,asp.net-core',
#  'single-page-application,c#,amazon-web-services,typescript,.net,c#,api,typescript,amazon-web-services,geolocation,typescript,knockout.js,c#,leaflet,google-maps',
#  'reactjs,node.js,web-services,salesforce,zendesk,node.js,security,postgresql,amazon-web-services,postgresql,mongodb,golang,python,java,saml,oauth,openid-connect,php,continuous-integration,wordpress,node.js,laravel',
#  '',
#  'postgresql,mongodb,golang,python,java,node.js,security,postgresql,amazon-web-services,reactjs,node.js,web-services,salesforce,zendesk,saml,oauth,openid-connect,php,continuous-integration,wordpress,node.js,laravel',
#  'reactjs,javascript,postgresql,nosql,project-management,product-management,qa,c#,android,ios,git,xamarin',
#  'windows-services,wpf,grpc,com,wcf',
#  'go,python,c,java-ee,hybris,spring,java',
#  'c#,asp.net,blazor,azure,kubernetes',
#  'cloud,kubernetes,api-design,google-cloud-platform,hashicorp-vault,amazon-web-services,ruby,tdd,python,ruby,docker,amazon-web-services,configuration-management,amazon-web-services,python,ruby',
#  'amazon-web-services,ruby,tdd,python,ruby,docker,amazon-web-services,configuration-management,cloud,kubernetes,api-design,google-cloud-platform,hashicorp-vault,amazon-web-services,python,ruby',
#  'javascript,shopify,reactjs,liquid,html,asp.net,javascript,c#,vb.net,.net,asp.net,c#,sql-server,html5,ajax',
#  'admin,user-management,device-manager,ou,cloud,c++,git,.net-core,.net,c#,cloud,ibm-cloud,azure-devops,on-prem,azure,linux',
#  'api,c#,.net',
#  'ruby,machine-learning,etl,amazon-redshift,javascript',
#  'java,spring-boot,hibernate,amazon-web-services,activemq,amazon-web-services,kubernetes,docker,terraform,linux',
#  'reactjs,angularjs,vue.js,frontend,web-applications,java,api,rest,microservices,web-applications,agile,product-management,saas,web-applications,erp',
#  'python,postgresql,flask,cherrypy,mongodb,python,postgres,mongodb,flask,django,python,flask,mongodb,javascript,reactjs,angular,angularjs,vue.js,reactjs,javascript,typescript,babel,cypress,kubernetes,amazon-web-services,python,docker,splunk',
#  'amazon-web-services,java,apache-spark,hadoop,hbase,python,security,ruby,java,javascript,security,python,ruby,java,javascript',
#  'ansible,kubernetes,sysadmin,devops',
#  'qa,testing,java,bigdata,artificial-intelligence,linux,python,devops',
#  'ios,objective-c,javascript,swift,xcode,javascript,vue.js,reactjs,angular,python,django,flask,react-native,flutter,javascript,ios,android,reactjs,react-redux,typescript,javascript,webpack,devops,amazon-web-services,docker,kubernetes',
#  'php,mysql,symfony,laravel,javascript,vue.js,reactjs,angular,python,django,flask,react-native,flutter,javascript,ios,android,reactjs,react-redux,typescript,javascript,webpack,devops,amazon-web-services,docker,kubernetes',
#  'go,security',
#  'javascript,reactjs,node.js,php,c#,terraform,ansible,amazon-web-services,go,postgresql,python,go,kubernetes,docker,amazon-web-services,reactjs,javascript,html,css,node.js,reactjs,ruby-on-rails,ruby,typescript,postgresql,reactjs,javascript,typescript',
#  'c#,.net,azure,docker,geospatial',
#  'saml,oauth,openid-connect,node.js,security,postgresql,amazon-web-services,postgresql,mongodb,golang,python,java,reactjs,node.js,web-services,salesforce,zendesk,php,continuous-integration,wordpress,node.js,laravel',
#  'pytorch,python,machine-learning,fast-ai,pipeline',
#  'python,javascript,react.js',
#  'c#,android,ios,git,xamarin,reactjs,javascript,postgresql,nosql,project-management,product-management,qa',
#  'java,backend,microservices,kubernetes,machine-learning',
#  'react-native,flutter,javascript,ios,android,javascript,vue.js,reactjs,angular,python,django,flask,reactjs,react-redux,typescript,javascript,webpack,devops,amazon-web-services,docker,kubernetes,node.js,javascript,express',
#  'java,c++,android,kotlin,java-native-interface,javascript,html,css',
#  'java,javascript,kubernetes,elasticsearch,nosql,java,javascript,kubernetes,elasticsearch,nosql,amazon-web-services,linux,kubernetes,docker,jenkins,sysadmin',
#  'android,mobile,ios,dart,flutter,android,mobile,ios,flutter,dart',
#  'javascript,node.js,typescript,documentation,node.js,javascript,graphql,typescript',
#  'angular,python,docker,api,debugging,sql,xml,json',
#  'react-native,node.js,mysql,webrtc,kurento,reactjs,node.js,javascript,react-native,websocket',
#  'google-analytics,instagram,facebook,seo,wordpress,javascript,node.js,html,web-deployment,python,sql,amazon-web-services,design,user-experience,html,css,balsamiq',
#  'c#,.net,back,javascript',
#  'automation,java,rest-assured,json,testng,java,spring-boot,amazon-web-services,stream,microservices',
#  'java,spring-boot,amazon-web-services,stream,microservices,automation,java,rest-assured,json,testng',
#  'security,node.js,amazon-web-services,javascript,typescript,node.js,api,typescript,microservices,integration,python,typescript,amazon-web-services,javascript,kubernetes,amazon-web-services,linux,rbac,apache-kafka,continuous-integration,hl7-fhir,api,continuous-integration,sql,api,hl7-fhir,json',
#  'swift,ios,firebase,reactjs,firebase,sass,next.js',
#  'spring,spring-security,spring-boot,java,scala,algorithm,sorting,data-structures,computer-science,time-complexity',
#  'go,machine-learning,python,node.js,javascript,vue.js,reactjs,angular,python,django,flask,react-native,flutter,javascript,ios,android,reactjs,react-redux,typescript,javascript,webpack,devops,amazon-web-services,docker,kubernetes',
#  'python,pyramid,postgresql,elasticsearch,security,amazon-web-services,terraform,postgresql,devops,sysadmin,reactjs,javascript,css,html,python',
#  'reactjs,javascript,css,html,python,python,pyramid,postgresql,elasticsearch,security,amazon-web-services,terraform,postgresql,devops,sysadmin',
#  'security,amazon-web-services,terraform,postgresql,devops,sysadmin,python,pyramid,postgresql,elasticsearch,reactjs,javascript,css,html,python',
#  'reactjs,frontend,web-frontend,web,javascript',
#  'sitecore,asp.net,c#,javascript,asp.net-core',
#  'writing,video',
#  'ruby-on-rails,ruby,amazon-web-services,postgresql',
#  'python,flask,docker,gcp,matillion,ansible,docker,python-2to3,flask,gunicorn,sysadmin',
#  'python,reactjs,django,flask,sql',
#  'node.js,security,postgresql,amazon-web-services,postgresql,mongodb,golang,python,java,reactjs,node.js,web-services,salesforce,zendesk,saml,oauth,openid-connect,php,continuous-integration,wordpress,node.js,laravel',
#  'mobile,android,ios,ionic2,ionic-framework,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql',
#  'android,ios,mobile,testing,automated-tests,robotframework,python,selenium,reactjs,sql,web-services,powerapps,office365',
#  'ruby-on-rails,ruby,sql,react-native,reactjs,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql',
#  'reactjs,android,ios,react-native,mobile,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,java,spring,java-ee,amazon-web-services,sql,mobile,android,ios,ionic2,ionic-framework',
#  'reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql,mobile,android,ios,ionic2,ionic-framework',
#  'agile,product-management,saas,web-applications,erp,java,api,rest,microservices,web-applications,reactjs,angularjs,vue.js,frontend,web-applications',
#  'kentico,cms,.net,c#,mvc',
#  'selenium,c#,mobile,qa,automation,c#,.net,xamarin,xamarin.forms,qa,automation,testing,selenium,oop,c#,web-services,html,angular,azure',
#  'reactjs,three.js,webgl,3d,javascript,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql,mobile,android,ios,ionic2,ionic-framework',
#  'sql,python,etl,database,bigdata,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,java,spring,java-ee,amazon-web-services,sql',
#  'java,spring,java-ee,amazon-web-services,sql,reactjs,javascript,node.js,express,sql,amazon-web-services,jenkins,docker,devops,kubernetes,reactjs,three.js,webgl,3d,javascript,reactjs,android,ios,react-native,mobile,mobile,android,ios,ionic2,ionic-framework',
#  'java,hybris,progressive-web-apps,spring,javascript,angularjs,angular,css,java,intershop,progressive-web-apps,angularjs',
#  'rest,web-services',
#  'javascript,angularjs,node.js,mongodb',
#  '',
#  'excel,ms-access,ms-office,ms-word,outlook,reactjs,javascript,node.js,css,api,javascript,reactjs,node.js,nosql,git,docker,gitlab,elasticsearch,logstash,php,symfony,mysql,typo3,extbase,python,c#,office365,ms-access,haskell-snap-framework',
#  'amazon-web-services,python,data-science,machine-learning,kotlin,qa,testing,android,web,ios',
#  'qa,testing,android,web,ios,amazon-web-services,python,data-science,machine-learning,kotlin',
#  'node.js,api,mongodb,architecture,caching',
#  'amazon-web-services,docker,pulumi,kubernetes,terraform',
#  'php,mysql,javascript,angularjs,ansible',
#  'python,ruby,docker,amazon-web-services,configuration-management,amazon-web-services,ruby,tdd,cloud,kubernetes,api-design,google-cloud-platform,hashicorp-vault,amazon-web-services,python,ruby',
#  'api,json,telephony,webrtc,sip',
#  'ruby-on-rails,postgresql,reactjs',
#  'c++,unix,.net,linux,json,c#,asp.net,javascript,mysql,object-oriented-analysis',
#  'c#,asp.net,javascript,mysql,object-oriented-analysis,c++,unix,.net,linux,json',
#  'ruby,postgresql,sequel,cuba,sinatra,c#,go,ruby,c#,.net,asp.net,.net-core,elixir,typescript,ruby,amazon-web-services,google-cloud-platform',
#  'elixir,graphql,postgresql,phoenix,erlang',
#  'java,bigdata,artificial-intelligence,qa,testing,linux,python,devops',
#  'javascript,vue.js,performance,seo,android,java,oop,kotlin,mysql,data-warehouse,etl,bigdata,infrastructure',
#  'android,java,oop,kotlin,javascript,vue.js,performance,seo,mysql,data-warehouse,etl,bigdata,infrastructure',
#  'git,php,python,magento,linux,python,go,symfony2',
#  'f5,terraform,ansible,azure,devops,sysadmin',
#  'node.js,javascript,graphql,typescript,javascript,node.js,typescript,documentation',
#  'ansible,amazon-web-services,devops,unix,jenkins,sysadmin',
#  'c#,asp.net-mvc,angular,azure,sql-server',
#  'go,javascript,mysql,vue.js,unix',
#  'socialengine',
#  'kubernetes,amazon-web-services,python,docker,splunk,python,postgres,mongodb,flask,django,python,postgresql,flask,cherrypy,mongodb,python,flask,mongodb,javascript,reactjs,angular,angularjs,vue.js,reactjs,javascript,typescript,babel,cypress',
#  'ios,objective-c,swift',
#  'amazon-web-services,angularjs,javascript,postgresql,reactjs,amazon-web-services,angular,react-bootstrap,node.js,docker',
#  'nightwatch.js,jenkins,automation,selenium,javascript,reactjs,javascript,node.js,npm,tdd,ios,swift,sdk,java,amazon-web-services,devops,amazon-rds,sql',
#  'javascript,css,html5',
#  'cloud,web-services,project-management,kubernetes,python,php,javascript,javascript,design,security,php,javascript,python',
#  'javascript,node.js,mongodb,vue.js,storybook,javascript,node.js,mongodb,vue.js,storybook,javascript,node.js,mongodb,vue.js,storybook',
#  'c++,git,.net-core,.net,c#,cloud,ibm-cloud,azure-devops,on-prem,azure,admin,user-management,device-manager,ou,cloud,linux',
#  'asp.net-core,azure-devops,microservices,.net-core,kubernetes,sysadmin',
#  'amazon-web-services,kubernetes,hangfire,redis,asp.net,angularjs,c#,angular,vue.js',
#  'java,javascript,css,sql,java-8,javascript,html,database,css,java,java,sql,jquery,web-services,rpg,java,spring,enterprise-architect,software-design,software-distribution,java,mysql,eclipse,solr,elasticsearch,java,javafx,spring,swing,swingx',
#  'java,mysql,eclipse,solr,elasticsearch,javascript,html,database,css,java,java,sql,jquery,web-services,rpg,java,javascript,css,sql,java-8,java,spring,enterprise-architect,software-design,software-distribution,java,javafx,spring,swing,swingx',
#  'python,c#,office365,ms-access,haskell-snap-framework,reactjs,javascript,node.js,css,api,javascript,reactjs,node.js,nosql,git,docker,gitlab,elasticsearch,logstash,php,symfony,mysql,typo3,extbase,excel,ms-access,ms-office,ms-word,outlook',
#  'python,cython,tensorflow,keras,pytorch,c++,data-structures,parallel-processing,amazon-s3,posix',
#  'apache-spark,scala,amazon-s3,amazon-kinesis,amazon-web-services',
#  'qa,testing,software-quality,sdlc,agile',
#  'php,html,css,javascript,lamp',
#  'php,python,sql,hadoop,amazon-web-services,php,mysql,wordpress,reactjs,javascript,wordpress,php,javascript',
#  'angularjs,reactjs,node.js,asp.net,node.js,reactjs,angularjs,asp.net,.net-core',
#  'php,mysql,wordpress,reactjs,javascript,wordpress,php,javascript,php,python,sql,hadoop,amazon-web-services',
#  'reactjs,node.js,typescript,kubernetes,graphql',
#  'python,bash,jenkins,amazon-web-services,powershell,sysadmin',
#  'asp.net,angularjs,c#,angular,vue.js,amazon-web-services,kubernetes,hangfire,redis',
#  'javascript,html5,progressive-web-apps,html5-canvas,p5.js,node.js,reactjs,docker,amazon-web-services,postgresql',
#  'cloud,python,sql,networking,tcp,qa,python,pytest,testing,jira,javascript,angularjs,python',
#  'php,reactjs,mysql,laravel,javascript,reactjs,mongodb,node.js,javascript,amazon-web-services,reactjs,javascript,automation,google-chrome-extension',
#  'reactjs,react-redux,redux,ecmascript-6,ecmascript-2017,ruby-on-rails,ruby,api,grape,rspec,infrastructure,amazon-s3,ansible,chef,devops',
#  'java,owasp,html,docker,reactjs,tdd,javascript,ruby,ruby-on-rails,rspec,reactjs,amazon-web-services,ruby,ruby-on-rails,rspec,reactjs,amazon-web-services',
#  'continuous-integration,hl7-fhir,api,node.js,api,typescript,microservices,integration,security,node.js,amazon-web-services,javascript,typescript,python,typescript,amazon-web-services,javascript,kubernetes,amazon-web-services,linux,rbac,apache-kafka,continuous-integration,sql,api,hl7-fhir,json',
#  'reactjs,sql,web-services,powerapps,office365,android,ios,mobile,testing,automated-tests,robotframework,python,selenium',
#  'go,kubernetes,cloud,kubernetes,go',
#  'kubernetes,grafana,go,backend',
#  'javascript,vue.js,reactjs,angular,python,django,flask,react-native,flutter,javascript,ios,android,reactjs,react-redux,typescript,javascript,webpack,devops,amazon-web-services,docker,kubernetes,node.js,javascript,express',
#  'node.js,python,sql,amazon-web-services',
#  'c#,web-services,html,angular,azure,c#,.net,xamarin,xamarin.forms,qa,automation,testing,selenium,oop,selenium,c#,mobile,qa,automation',
#  'node.js,reactjs,angularjs,asp.net,.net-core,angularjs,reactjs,node.js,asp.net',
#  'c#,.net,asp.net,.net-core,ruby,postgresql,sequel,cuba,sinatra,c#,go,ruby,elixir,typescript,ruby,amazon-web-services,google-cloud-platform',
#  'php,python,git,sql,security,php,node.js,angular,python,github']

# %% [markdown]
# ## Add technologies to DataFrame

# %%
df["Technologies"] = description_technologies
df
# Out:
#                                                 Titles  \
# 0                       Software Engineer - DevOps/SRE
# 1    DevOps Engineer (Go, Terraform, Ansible, AWS) ...
# 2                   Systems Administrator (Linux, PHP)
# 3                 Managed Service System Engineer - US
# 4             PHP-/Symfony-Entwickler (m/w/d) gesucht!
# ..                                                 ...
# 170        Data Engineer (Contract, £350-£550/day DoE)
# 171                     Senior Web Developer (Angular)
# 172             Lead Technical Support & Test Engineer
# 173        Experienced Backend Engineer - C#/.Net Core
# 174                        Principal Software Engineer
#
#                                                  Links  \
# 0    https://stackoverflow.com/jobs/369052/software...
# 1    https://stackoverflow.com/jobs/377997/devops-e...
# 2    https://stackoverflow.com/jobs/357276/systems-...
# 3    https://stackoverflow.com/jobs/301008/managed-...
# 4    https://stackoverflow.com/jobs/275301/php-symf...
# ..                                                 ...
# 170  https://stackoverflow.com/jobs/299629/data-eng...
# 171  https://stackoverflow.com/jobs/202880/senior-w...
# 172  https://stackoverflow.com/jobs/374521/lead-tec...
# 173  https://stackoverflow.com/jobs/352087/experien...
# 174  https://stackoverflow.com/jobs/374393/principa...
#
#                                           Technologies
# 0        google-cloud-platform,kubernetes,python,azure
# 1    terraform,ansible,amazon-web-services,go,postg...
# 2                                     devops,php,linux
# 3        linux,web-services,linux,tomcat,apache,python
# 4    php,android,symfony,reactjs,javascript,node.js...
# ..                                                 ...
# 170             node.js,python,sql,amazon-web-services
# 171  c#,web-services,html,angular,azure,c#,.net,xam...
# 172  node.js,reactjs,angularjs,asp.net,.net-core,an...
# 173  c#,.net,asp.net,.net-core,ruby,postgresql,sequ...
# 174  php,python,git,sql,security,php,node.js,angula...
#
# [175 rows x 3 columns]
